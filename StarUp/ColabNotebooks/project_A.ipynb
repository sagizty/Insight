# %% [markdown]
# # Check GPU

# %%
# check GPU
# !nvidia-smi
# Out:
# Mon Aug  8 12:32:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    31W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Arrange the files

# %%
# create file-system enviroment
# mount the google drive first
# https://drive.google.com/drive/u/1/my-drive

# clear colab path
# !rm -rf /home/XZH

# create path
# !mkdir /home/XZH
# !mkdir /home/XZH/data
# !mkdir /home/XZH/runs
# !mkdir /home/XZH/code
# !mkdir /home/XZH/saved_models
# !mkdir /home/XZH/imaging_results

print('Folder Tree Creation completed!')

# get the latest code from Github MIL-SI official page
# !git clone https://github.com/DELTAXZH/StartUp.git /home/XZH/code
print('code transfer from github completed!')

# get the dataset by its zip
# !cp /content/drive/MyDrive/dataset/warwick_CLS.zip /home/XZH/data/
# unzip
# !unzip -q /home/XZH/data/warwick_CLS.zip -d /home/XZH/data/
# alter the path
# !rm -rf /home/XZH/data/warwick_CLS.zip
print('data transfer completed!')
# Out:
# Folder Tree Creation completed!
# Cloning into '/home/XZH/code'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.
# code transfer from github completed!
# data transfer completed!

# %% [markdown]
# # Arrange the enviroment

# %%
# change working dir
import os
os.chdir("/home/XZH/code")
# !pwd

# get packages
# !pip install tensorboardX
# !pip install timm
# !pip install notifyemail
# !pip install ttach
# Out:
# /home/XZH/code
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 14.8 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 509 kB 14.7 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Run codes

# %%
# !python project_a.py
# Out:
# Finished Step 0 : enviroment preparing
# Finished Step 1 : data preparing
# Finished Step 2 : build a model (Transfer learning)
# Finished Step 3 : set optimizer and loss
# Epoch 0/9
# ----------
# train Loss: 1.0781 Acc: 0.6232
# val Loss: 0.2098 Acc: 0.9375
#
# Epoch 1/9
# ----------
# train Loss: 0.1028 Acc: 0.9855
# val Loss: 0.1272 Acc: 0.8750
#
# Epoch 2/9
# ----------
# train Loss: 0.0233 Acc: 1.0000
# val Loss: 0.0538 Acc: 1.0000
#
# Epoch 3/9
# ----------
# train Loss: 0.0885 Acc: 0.9565
# val Loss: 0.1143 Acc: 0.9375
#
# Epoch 4/9
# ----------
# train Loss: 0.0348 Acc: 0.9855
# val Loss: 0.0977 Acc: 0.9375
#
# Epoch 5/9
# ----------
# train Loss: 0.0440 Acc: 0.9710
# val Loss: 0.0286 Acc: 1.0000
#
# Epoch 6/9
# ----------
# train Loss: 0.0305 Acc: 0.9855
# val Loss: 0.1499 Acc: 0.9375
#
# Epoch 7/9
# ----------
# train Loss: 0.0139 Acc: 1.0000
# val Loss: 0.1383 Acc: 0.9375
#
# Epoch 8/9
# ----------
# train Loss: 0.0058 Acc: 1.0000
# val Loss: 0.1337 Acc: 0.9375
#
# ...
