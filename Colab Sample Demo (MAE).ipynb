# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>Colab 实验平台使用模板，以MAE为例</h1>
#
# # 根据如下步骤熟悉如何使用CoLab实验平台
#
# 12/19/2021 by：张天翊
#
# * 简介：colab是一个虚拟的服务器分发平台，每次会分给你一个服务器（cpu 56G内存+ 某个GPU）使用可以在后台执行最多24h
#
# * 优点：可以记录结果 + 交互式计算 + 给大家类似本地linux服务器的环境 + 提供论文复现环境
# * 为了最大化大家的内卷效率：
# 实验室决定把多个人学习程序的时候在这个上面执行，或者是短时间的/有复现需求的任务放在colab上，正式长时间模型还是在线下linux服务器跑（路径配置与colab相同）

# %% [markdown]
# # 本例子中的文件系统
#
# ## 服务器路径结构：
# * /home 工作目录
# * /home/Insight 项目文件路径
# * /home/Insight/runs 存放tensorboard输出
# * /home/Insight/saved_models 存模型
# * /home/Insight/code 代码总目录（与github一样）
# * /home/Insight/code/colab_sample 某某 colab_sample的 个人代码路径（与pycharm同步路径一致）
#
#
# * /data 数据目录
# * /data/Insight 项目数据路径
# * /data/Insight/samole_data.zip 数据集压缩包（或文件夹）
#
#
# ## github路径结构
# * /Insight     项目的总路径
# * /Insight/colab_sample 个人(colab_sample)代码文件夹
#
# ## pycharm同步文件夹
# * 将本地代码文件夹 与服务器上的/home/Insight/code/colab_sample 个人代码文件夹 同步即可
#
# ## Google Drive路径结构
# * /mydrive/Insight/code
# * /mydrive/Insight/runs
# * /mydrive/Insight/saved_models
# * /mydrive/dataset/samole_data.zip 数据集压缩包

# %% [markdown]
# # 配置运行时资源
# * 在开始之前根据需要先把实例切换成gpu+高RAM （右上角'链接'-'查看资源'-'更改运行时类型'的位置设置RAM磁盘啥的，默认的不一定合适）
# * 硬件加速器选None表示这个是CPU环境，选GPU调用有显卡的服务器来进行实验，TPU则只支持基于tensorflow、keras写的代码，我们统一使用PPytorch
#
# * 管理会话查看正在运行的运行时（右上角'链接'-'查看资源'-'管理会话'，注意别把别人的终止掉了）
#
#
# # 检查显卡
#
# * 首先检查用的什么卡，最好是v100、P100（这两个区别不是很大）不行的话就T4，再不行就躺平吧
# * 目前发现可以开1-3个notebook跑，也就是最多可以用3个单卡环境，无法多卡交互
#
# * 如果显示：NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running. 表示没有显卡

# %%
# 查看显卡类型，感叹号在ipynb调用linux指令
# !nvidia-smi
# Out:
# Sun Apr 17 07:45:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 显示时间

# %%
# 如果一段时间不需要用显卡的话，可以整个僵尸参数占用点显存，避免出现警告
# import torch
# a = torch.Tensor([1000, 1000, 1000]).cuda()  # 大约占用 1.1G 显存
# !date --date='+8 hour'  # 查看系统时间，转换为北京时间
# Out:
# Sun Apr 17 15:45:52 UTC 2022

# %% [markdown]
# # 挂载Google Drive
#
# * 直接执行会需要点链接验证，点确定就行
# * 或 点击 左边菜单栏 文件-回收文件夹的符号实现挂载

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 挂载Github（调取公用账号，给予colab代码库权限）
# 用来把代码库从github上拿下来，并装载到colab虚拟机上
#
# ref: https://blog.csdn.net/u011119817/article/details/108722832
# ref: https://docs.github.com/en/github/authenticating-to-github/keeping-your-account-and-data-secure/creating-a-personal-access-token

# %%
import os
# GitHub user
user = 'Idonttellu'
# GitHub personal-access-token
password = 'Idonttellu'
os.environ['GITHUB_AUTH'] = user + ':' + password

# %% [markdown]
# ## 创建文件 与 建立路径环境
# * 在此之前，先挂载google云盘。云盘上已经有数据了（[这是云盘的地址](https://drive.google.com/drive/u/1/my-drive)）：

# %%
# 创建文件
# 在此之前，先挂载google云盘。云盘上已经有代码和数据了，访问下面的网址可以增删内容：
# https://drive.google.com/drive/u/1/my-drive

# 先清空CoLab（用于避免重复执行的bug）
# !rm -rf /data
# !rm -rf /home/Insight

# 建立实验路径文件夹环境（与本地实验室linux服务器一致，便于代码直接在本地跑）
# !mkdir /home/Insight  # 实验路径
# !mkdir /home/Insight/runs  # 存tensorboard输出+json输出的路径
# !mkdir /home/Insight/code  # 存代码的路径
# !mkdir /home/Insight/saved_models  # 存模型的路径

# !mkdir /data  # 数据路径
# !mkdir /data/Insight

print('Folder Tree Creation completed!')

# 复制代码（来自colab）
# !cp -r /content/drive/MyDrive/zhanglab_headneck/Insight/* /home/zhanglab_headneck/Insight/code
# print('code transfer from colab completed!')

# 复制代码（来自github）大家的代码都加载到虚拟机/home/Insight/code，之后进入自己的代码文件夹
# !git clone https://github.com/sagizty/Insight.git /home/Insight/code
print('code transfer from github completed!')

# 如果是私有仓库需要登陆密码，使用方法如下，加一个$GITHUB_AUTH@,注意前面需要赋值，
# 该账号需要有权限访问私有仓库，因此在自己的仓库把公用账号Idonttellu拉进来就行
# !git clone https://$GITHUB_AUTH@github.com/sagizty/Insight.git /home/Insight/code

# 复制runs(除非对比需要调用，否则不应使用，节约时间)
# !cp -r /content/drive/MyDrive/zhanglab_headneck/runs/* /home/zhanglab_headneck/runs
# print('tensorboard log transfer completed!')

# 复制已有模型(除非调用已有模型，否则不应使用，节约时间，*代表全部，可以根据需要只要部分)
# !cp -r /content/drive/MyDrive/zhanglab_headneck/saved_models/* /home/zhanglab_headneck/saved_models
# print('model state dicts transfered')

# 复制数据集
# 复制压缩包
# !cp /content/drive/MyDrive/dataset/sample_data.zip /data/Insight/
# 解压缩(生成coco文件夹 /data/zhanglab_headneck/coco)
# !unzip -q /data/Insight/sample_data.zip -d /data/Insight/
# 调整删除zip
# !rm -f /data/Insight/sample_data.zip
print('data transfer completed!')
# Out:
# Folder Tree Creation completed!
# Cloning into '/home/Insight/code'...
# remote: Enumerating objects: 395, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (252/252), done.
# remote: Total 395 (delta 106), reused 0 (delta 0), pack-reused 131
# Receiving objects: 100% (395/395), 28.00 MiB | 16.76 MiB/s, done.
# Resolving deltas: 100% (164/164), done.
# code transfer from github completed!
# data transfer completed!

# %% [markdown]
# ## 安装库与程序环境
#
# ## 之后把工作路径切换到自己的文件夹！！！！！！！！！！！！

# %%
# 切换工作目录(请切换到自己的文件夹！！！！！！！！！！！！)
import os
my_file = 'colab_sample' # 切换工作目录(请切换到自己的文件夹！！！！！！！！！！！！)

my_path = os.path.join("/home/Insight/code", my_file)
os.chdir(my_path)

# 输出工作路径
# !pwd

# 安装依赖
# !pip install tensorboardX
# !pip install timm
# !pip install notifyemail
# 关于：使用tensorboard
# https://blog.csdn.net/wry3482/article/details/105930449
# https://zhuanlan.zhihu.com/p/64479055
# https://www.jianshu.com/p/86f7373160bf

# 保存和加载训练到一半的模型
# https://www.cnblogs.com/xiximayou/p/12450761.html
# Out:
# /home/Insight/code/colab_sample
# Collecting tensorboardX
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 14.9 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.5)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 14.7 MB/s
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.11.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# Collecting notifyemail
#   Downloading notifyemail-1.0.2-py3-none-any.whl (31 kB)
# Installing collected packages: notifyemail
# Successfully installed notifyemail-1.0.2

# %% [markdown]
# ## 开始正式内容
# * 命令行直接调用代码即可(前面用！代表是传给系统的linux指令，不然就传给python 解释器了）
# * 这种情况下使用Parser调节参数设置即可
#
# * 或者直接写脚本，如果比较简单的话

# %% [markdown]
# # 第一种用法是直接把虚拟机作为linux服务器，使用命令行调用执行代码，推荐
#
# ---

# %% [markdown]
# 前面:
# 1. 我们把github的代码装载到了服务器上
# 2. 我们已经切换到了虚拟机上自己的代码文件夹 /home/Insight/code/colab_sample

# %%
# !python sample.py  # 直接用!python叫系统执行
# Out:
# hello world
# working path: /home/Insight/code/colab_sample
# 7
# 2
# 3
# 1
# 5
# 6
# 4
# hello colab-github！！！

# %% [markdown]
# # 第二种用法是直接把python写在这里，这种方法主要是为了小调试，不推荐
#
# ---

# %%
'''
MAE 简单复现  ver: 2021.12.11
本实验是单个图片的MAE复现，意在说明MAE的过程。
本身没有进行代码结构性与逻辑细节的优化。
这个里面用的vit和我们习惯的timm版本略有不同，后续需要做匹配
总的来说，这个脚本作为一个流程例子用来学习MAE流程和部分细节还是不错的，
但是需要匹配性的重新做才可以使用到论文中。
这个脚本离真正论文能用的还有很远距离。
来自：https://zhuanlan.zhihu.com/p/439554945

加了训练脚本（但是是单张图片的，后续进一步优化）
我加了一些内容和注释,并且修改成了适配timm的样子
'''
import matplotlib.pyplot as plt
from PIL import Image
import timm
import torch, os
import torch.optim as optim
from Transformers import *
from tensorboardX import SummaryWriter


class MAE(nn.Module):
    def __init__(self, encoder, decoder_dim, mask_ratio=0.75, decoder_depth=1,
                 num_decoder_heads=8, decoder_dim_per_head=64):
        """
        MAE 框架，自带decoder模块
        :param encoder: 输入Transformer模型
        :param decoder_dim: Encoder 输出的维度可能和 Decoder 要求的输入维度不一致
        :param mask_ratio: paper提倡这个比例最好是 75%
        :param decoder_depth: 实质就是多层堆叠的 Transformer（这个也有一个gap问题，前后结构是否一样值得研究） TODO
        :param num_decoder_heads:
        :param decoder_dim_per_head:
        """
        super().__init__()
        assert 0. < mask_ratio < 1., f'mask ratio must be kept between 0 and 1, got: {mask_ratio}'

        # Encoder(这里 CW 用 ViT 实现)
        self.encoder = encoder
        self.patch_h = encoder.patch_embed.patch_size[0]
        self.patch_w = encoder.patch_embed.patch_size[1]

        encoder_dim = encoder.embed_dim

        channels = 3
        patch_dim = channels * self.patch_h * self.patch_w

        # 由于原生的 ViT 有 cls_token，因此其 position embedding 的倒数第2个维度是：
        # 实际划分的 patch 数量加上 1个 cls_token
        # num_patches_plus_cls_token, encoder_dim = encoder.pos_embed.shape[-2:]  fixme 之前不匹配
        num_patches_plus_cls_token = encoder.patch_embed.num_patches + 1

        # Patch embedding 后续考虑做成使用encoder的，但是原文使用的是MLP映射而不是CNN映射
        self.patch_embed = nn.Linear(patch_dim, encoder_dim)

        # Input channels of encoder patch embedding: patch size**2 x 3
        # 这个用作预测头部的输出通道，从而能够对 patch 中的所有像素值进行预测
        num_pixels_per_patch = encoder_dim  # encoder.patch_embed.weight.size(1)  fixme 之前不匹配
        # print(num_pixels_per_patch)

        # Encoder-Decoder：Encoder 输出的维度可能和 Decoder 要求的输入维度不一致，因此需要转换
        self.enc_to_dec = nn.Linear(encoder_dim, decoder_dim) if encoder_dim != decoder_dim else nn.Identity()

        # Mask token
        # paper提倡这个比例最好是 75%
        self.mask_ratio = mask_ratio
        # mask token 的实质：1个可学习的共享向量
        self.mask_embed = nn.Parameter(torch.randn(decoder_dim))

        # Decoder：实质就是多层堆叠的 Transformer
        self.decoder = Transformer(
            decoder_dim,
            decoder_dim * 4,
            depth=decoder_depth,
            num_heads=num_decoder_heads,
            dim_per_head=decoder_dim_per_head,
        )
        # 在 Decoder 中用作对 mask tokens 的 position embedding
        # Filter out cls_token 注意第1个维度去掉 cls_token
        self.decoder_pos_embed = nn.Embedding(num_patches_plus_cls_token - 1, decoder_dim)

        # Prediction head 输出的维度数等于1个 patch 的像素值数量
        self.head = nn.Linear(decoder_dim, num_pixels_per_patch)

    def forward(self, x):
        device = x.device
        b, c, h, w = x.shape

        '''i. Patch partition'''
        # 首先需要将图像划分成 patch，划分方式实质就是维度的变换
        num_patches = (h // self.patch_h) * (w // self.patch_w)
        # (b, c=3, h, w)->(b, n_patches, patch_size**2*c)
        patches = x.view(
            b, c,
            h // self.patch_h, self.patch_h,
            w // self.patch_w, self.patch_w
        ).permute(0, 2, 4, 3, 5, 1).reshape(b, num_patches, -1)

        '''ii. Divide into masked & un-masked groups'''

        # 根据 mask 比例计算需要 mask 掉的 patch 数量
        # num_patches = (h // self.patch_h) * (w // self.patch_w)
        num_masked = int(self.mask_ratio * num_patches)

        # Shuffle:生成对应 patch 的随机索引
        # torch.rand() 服从均匀分布(normal distribution)
        # torch.rand() 只是生成随机数，argsort() 是为了获得成索引
        # (b, n_patches)
        shuffle_indices = torch.rand(b, num_patches, device=device).argsort()
        # mask 和 unmasked patches 对应的索引
        mask_ind, unmask_ind = shuffle_indices[:, :num_masked], shuffle_indices[:, num_masked:]

        # 对应 batch 维度的索引：(b,1)
        batch_ind = torch.arange(b, device=device).unsqueeze(-1)
        # 利用先前生成的索引对 patches 进行采样，分为 mask 和 unmasked 两组 TODO
        mask_patches, unmask_patches = patches[batch_ind, mask_ind], patches[batch_ind, unmask_ind]

        '''iii. Encode'''

        # 将 patches 通过 emebdding 转换成 tokens
        unmask_tokens = self.patch_embed(unmask_patches)
        # unmask_tokens = self.encoder.patch_embed(unmask_patches)  fixme 之前不匹配

        # 为 tokens 加入 position embeddings
        # 注意这里索引加1是因为索引0对应 ViT 的 cls_token
        unmask_tokens += self.encoder.pos_embed.repeat(b, 1, 1)[batch_ind, unmask_ind + 1]
        # 真正的编码过程
        encoded_tokens = self.encoder.blocks(unmask_tokens)
        # encoded_tokens = self.encoder.transformer(unmask_tokens)  fixme 之前不匹配

        '''iv. Decode'''

        # 对编码后的 tokens 维度进行转换，从而符合 Decoder 要求的输入维度
        enc_to_dec_tokens = self.enc_to_dec(encoded_tokens)

        # 由于 mask token 实质上只有1个，因此要对其进行扩展，从而和 masked patches 一一对应
        # (decoder_dim)->(b, n_masked, decoder_dim)
        mask_tokens = self.mask_embed[None, None, :].repeat(b, num_masked, 1)
        # 为 mask tokens 加入位置信息
        mask_tokens += self.decoder_pos_embed(mask_ind)

        # 将 mask tokens 与 编码后的 tokens 拼接起来
        # (b, n_patches, decoder_dim)
        concat_tokens = torch.cat([mask_tokens, enc_to_dec_tokens], dim=1)
        # Un-shuffle：恢复原先 patches 的次序
        dec_input_tokens = torch.empty_like(concat_tokens, device=device)
        dec_input_tokens[batch_ind, shuffle_indices] = concat_tokens
        # 将全量 tokens 喂给 Decoder 解码
        decoded_tokens = self.decoder(dec_input_tokens)

        '''v. Mask pixel Prediction'''

        dec_mask_tokens = decoded_tokens[batch_ind, mask_ind, :]
        # (b, n_masked, n_pixels_per_patch=patch_size**2 x c)
        pred_mask_pixel_values = self.head(dec_mask_tokens)

        return pred_mask_pixel_values, mask_patches

    # @torch.no_grad
    def predict(self, x):
        self.eval()

        device = x.device
        b, c, h, w = x.shape

        '''i. Patch partition'''

        num_patches = (h // self.patch_h) * (w // self.patch_w)
        # (b, c=3, h, w)->(b, n_patches, patch_size**2*c)
        patches = x.view(
            b, c,
            h // self.patch_h, self.patch_h,
            w // self.patch_w, self.patch_w
        ).permute(0, 2, 4, 3, 5, 1).reshape(b, num_patches, -1)

        '''ii. Divide into masked & un-masked groups'''

        num_masked = int(self.mask_ratio * num_patches)

        # Shuffle
        # (b, n_patches)
        shuffle_indices = torch.rand(b, num_patches, device=device).argsort()
        mask_ind, unmask_ind = shuffle_indices[:, :num_masked], shuffle_indices[:, num_masked:]

        # (b, 1)
        batch_ind = torch.arange(b, device=device).unsqueeze(-1)
        mask_patches, unmask_patches = patches[batch_ind, mask_ind], patches[batch_ind, unmask_ind]

        '''iii. Encode'''

        # unmask_tokens = self.encoder.patch_embed(unmask_patches)  fixme 之前不匹配
        unmask_tokens = self.patch_embed(unmask_patches)

        # Add position embeddings
        unmask_tokens += self.encoder.pos_embed.repeat(b, 1, 1)[batch_ind, unmask_ind + 1]
        # encoded_tokens = self.encoder.transformer(unmask_tokens)  fixme 之前不匹配
        encoded_tokens = self.encoder.blocks(unmask_tokens)
        '''iv. Decode'''

        enc_to_dec_tokens = self.enc_to_dec(encoded_tokens)

        # (decoder_dim)->(b, n_masked, decoder_dim)
        mask_tokens = self.mask_embed[None, None, :].repeat(b, num_masked, 1)
        # Add position embeddings
        mask_tokens += self.decoder_pos_embed(mask_ind)

        # (b, n_patches, decoder_dim)
        concat_tokens = torch.cat([mask_tokens, enc_to_dec_tokens], dim=1)
        # dec_input_tokens = concat_tokens
        dec_input_tokens = torch.empty_like(concat_tokens, device=device)
        # Un-shuffle
        dec_input_tokens[batch_ind, shuffle_indices] = concat_tokens
        decoded_tokens = self.decoder(dec_input_tokens)

        '''v. Mask pixel Prediction'''

        dec_mask_tokens = decoded_tokens[batch_ind, mask_ind, :]
        # (b, n_masked, n_pixels_per_patch=patch_size**2 x c)
        pred_mask_pixel_values = self.head(dec_mask_tokens)

        # 比较下预测值和真实值
        mse_per_patch = (pred_mask_pixel_values - mask_patches).abs().mean(dim=-1)
        mse_all_patches = mse_per_patch.mean()

        print(f'mse per (masked)patch: {mse_per_patch} mse all (masked)patches: {mse_all_patches} '
              f'total {num_masked} masked patches')
        print(f'all close: {torch.allclose(pred_mask_pixel_values, mask_patches, rtol=1e-1, atol=1e-1)}')

        '''vi. Reconstruction'''

        recons_patches = patches.detach()
        # Un-shuffle (b, n_patches, patch_size**2 * c)
        recons_patches[batch_ind, mask_ind] = pred_mask_pixel_values
        # 模型重建的效果图
        # Reshape back to image
        # (b, n_patches, patch_size**2 * c)->(b, c, h, w)
        recons_img = recons_patches.view(
            b, h // self.patch_h, w // self.patch_w,
            self.patch_h, self.patch_w, c
        ).permute(0, 5, 1, 3, 2, 4).reshape(b, c, h, w)

        mask_patches = torch.randn_like(mask_patches, device=mask_patches.device)
        # mask 效果图
        patches[batch_ind, mask_ind] = mask_patches
        patches_to_img = patches.view(
            b, h // self.patch_h, w // self.patch_w,
            self.patch_h, self.patch_w, c
        ).permute(0, 5, 1, 3, 2, 4).reshape(b, c, h, w)

        return recons_img, patches_to_img


def train(mae, dataloader, optimizer, criterion, epoch=1000, writer=None):

    for i in range(epoch):
        img_ts=dataloader  # TODO 这个只是假的dataloader
        pred_mask_pixel_values, mask_patches = mae(img_ts)
        optimizer.zero_grad()
        loss = criterion(pred_mask_pixel_values, mask_patches)

        loss.backward()
        optimizer.step()
        # 比较下预测值和真实值
        mse_per_patch = (pred_mask_pixel_values - mask_patches).abs().mean(dim=-1)
        mse_all_patches = mse_per_patch.mean()
        print(f'Epoch: {i+1} ')
        print(f'mse all (masked)patches: {mse_all_patches} ')
        print(f'all close: {torch.allclose(pred_mask_pixel_values, mask_patches, rtol=1e-1, atol=1e-1)}')

        if writer is not None:
            # ...log the running loss
            writer.add_scalar('train' + ' minibatch loss',
                              float(mse_all_patches),
                              i)
    # 结束记录内容给tensorboard
    if writer is not None:
        writer.close()

# %% [markdown]
# 分段执行，和jyputer一样

# %%
BASE_DIR = r'./'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

draw_path = '/home/Insight/runs/MAE'
save_model_path = '/home/Insight/saved_models'
if not os.path.exists(draw_path):
    os.makedirs(draw_path)
if not os.path.exists(save_model_path):
    os.makedirs(save_model_path)

writer = SummaryWriter(draw_path)

# 读入图像并缩放到适合模型输入的尺寸
img_raw = Image.open(os.path.join(BASE_DIR, 'photo.jpg'))
h, w = img_raw.height, img_raw.width
ratio = h / w
print(f"image hxw: {h} x {w} mode: {img_raw.mode}")

img_size, patch_size = (224, 224), (16, 16)
img = img_raw.resize(img_size)
rh, rw = img.height, img.width
print(f'resized image hxw: {rh} x {rw} mode: {img.mode}')
img.save(os.path.join(BASE_DIR, 'resized_photo.jpg'))

# 将图像转换成张量
from torchvision.transforms import ToTensor, ToPILImage

img_ts = ToTensor()(img).unsqueeze(0).to(device)
print(f"input tensor shape: {img_ts.shape} dtype: {img_ts.dtype} device: {img_ts.device}")

# 实例化模型
# encoder = ViT(img_size, patch_size, dim=512, mlp_dim=1024, dim_per_head=64)
encoder = timm.create_model('vit_base_patch16_224', pretrained=True, num_classes=1000)
decoder_dim = 512
mae = MAE(encoder, decoder_dim, decoder_depth=6)
# weight = torch.load(os.path.join(BASE_DIR, 'mae.pth'), map_location='cpu')  # 加载训练好的权重
mae.to(device)

# 训练
criterion = nn.MSELoss()
optimizer = optim.Adam(mae.parameters(), lr=0.0001, weight_decay=0.01)

train(mae, img_ts, optimizer, criterion, epoch=1000, writer=writer)  # TODO 这个用的假dataloader

torch.save(mae.state_dict(), os.path.join(save_model_path,'MAE.pth'))
# Out:
# image hxw: 951 x 886 mode: RGB
# resized image hxw: 224 x 224 mode: RGB
# input tensor shape: torch.Size([1, 3, 224, 224]) dtype: torch.float32 device: cuda:0
# Epoch: 1
# mse all (masked)patches: 0.8639051914215088
# all close: False
# Epoch: 2
# mse all (masked)patches: 0.701176106929779
# all close: False
# Epoch: 3
# mse all (masked)patches: 0.6338961720466614
# all close: False
# Epoch: 4
# mse all (masked)patches: 0.6046916842460632
# all close: False
# Epoch: 5
# mse all (masked)patches: 0.5863736867904663
# all close: False
# Epoch: 6
# mse all (masked)patches: 0.5727626085281372
# all close: False
# Epoch: 7
# mse all (masked)patches: 0.559879720211029
# all close: False
# Epoch: 8
# mse all (masked)patches: 0.5512166619300842
# all close: False
# Epoch: 9
# mse all (masked)patches: 0.5394402146339417
# all close: False
# Epoch: 10
# mse all (masked)patches: 0.5304932594299316
# all close: False
# Epoch: 11
# mse all (masked)patches: 0.5240459442138672
# all close: False
# Epoch: 12
# mse all (masked)patches: 0.5204212069511414
# all close: False
# Epoch: 13
# mse all (masked)patches: 0.5107011795043945
# all close: False
# Epoch: 14
# mse all (masked)patches: 0.4989766776561737
# all close: False
# Epoch: 15
# mse all (masked)patches: 0.49673372507095337
# all close: False
# Epoch: 16
# mse all (masked)patches: 0.48766782879829407
# all close: False
# Epoch: 17
# mse all (masked)patches: 0.4794529378414154
# all close: False
# Epoch: 18
# mse all (masked)patches: 0.4743230938911438
# all close: False
# Epoch: 19
# mse all (masked)patches: 0.47495678067207336
# all close: False
# Epoch: 20
# mse all (masked)patches: 0.46635332703590393
# all close: False
# Epoch: 21
# mse all (masked)patches: 0.46156954765319824
# all close: False
# Epoch: 22
# mse all (masked)patches: 0.4608357548713684
# all close: False
# Epoch: 23
# mse all (masked)patches: 0.46226105093955994
# all close: False
# Epoch: 24
# mse all (masked)patches: 0.4539899528026581
# all close: False
# Epoch: 25
# mse all (masked)patches: 0.4525796175003052
# all close: False
# Epoch: 26
# mse all (masked)patches: 0.450038343667984
# all close: False
# Epoch: 27
# mse all (masked)patches: 0.44615572690963745
# all close: False
# Epoch: 28
# mse all (masked)patches: 0.44530168175697327
# all close: False
# Epoch: 29
# mse all (masked)patches: 0.44169729948043823
# all close: False
# Epoch: 30
# mse all (masked)patches: 0.43994301557540894
# all close: False
# Epoch: 31
# mse all (masked)patches: 0.4322627782821655
# all close: False
# Epoch: 32
# mse all (masked)patches: 0.43558257818222046
# all close: False
# Epoch: 33
# mse all (masked)patches: 0.4333517849445343
# all close: False
# Epoch: 34
# mse all (masked)patches: 0.42885100841522217
# all close: False
# Epoch: 35
# mse all (masked)patches: 0.42615580558776855
# all close: False
# Epoch: 36
# mse all (masked)patches: 0.4188821315765381
# all close: False
# Epoch: 37
# mse all (masked)patches: 0.424525648355484
# all close: False
# Epoch: 38
# mse all (masked)patches: 0.41895994544029236
# all close: False
# Epoch: 39
# mse all (masked)patches: 0.4180571734905243
# all close: False
# Epoch: 40
# mse all (masked)patches: 0.4181917607784271
# all close: False
# Epoch: 41
# mse all (masked)patches: 0.4144126772880554
# all close: False
# Epoch: 42
# mse all (masked)patches: 0.40981757640838623
# all close: False
# Epoch: 43
# mse all (masked)patches: 0.41027647256851196
# all close: False
# Epoch: 44
# mse all (masked)patches: 0.4066788852214813
# all close: False
# Epoch: 45
# mse all (masked)patches: 0.4022556245326996
# all close: False
# Epoch: 46
# mse all (masked)patches: 0.39970189332962036
# all close: False
# Epoch: 47
# mse all (masked)patches: 0.40197864174842834
# all close: False
# Epoch: 48
# mse all (masked)patches: 0.4010923504829407
# all close: False
# Epoch: 49
# mse all (masked)patches: 0.3999311029911041
# all close: False
# Epoch: 50
# mse all (masked)patches: 0.401620477437973
# all close: False
# Epoch: 51
# mse all (masked)patches: 0.3944433331489563
# all close: False
# Epoch: 52
# mse all (masked)patches: 0.39514705538749695
# all close: False
# Epoch: 53
# mse all (masked)patches: 0.3930519223213196
# all close: False
# Epoch: 54
# mse all (masked)patches: 0.39015907049179077
# all close: False
# Epoch: 55
# mse all (masked)patches: 0.39220109581947327
# all close: False
# Epoch: 56
# mse all (masked)patches: 0.3870716392993927
# all close: False
# Epoch: 57
# mse all (masked)patches: 0.38801342248916626
# all close: False
# Epoch: 58
# mse all (masked)patches: 0.38642778992652893
# all close: False
# Epoch: 59
# mse all (masked)patches: 0.3838232159614563
# all close: False
# Epoch: 60
# mse all (masked)patches: 0.38166049122810364
# all close: False
# Epoch: 61
# mse all (masked)patches: 0.38275545835494995
# all close: False
# Epoch: 62
# mse all (masked)patches: 0.378233939409256
# all close: False
# Epoch: 63
# mse all (masked)patches: 0.38038814067840576
# all close: False
# Epoch: 64
# mse all (masked)patches: 0.377549409866333
# all close: False
# Epoch: 65
# mse all (masked)patches: 0.37515121698379517
# all close: False
# Epoch: 66
# mse all (masked)patches: 0.37098413705825806
# all close: False
# Epoch: 67
# mse all (masked)patches: 0.37123140692710876
# all close: False
# Epoch: 68
# mse all (masked)patches: 0.365955114364624
# all close: False
# Epoch: 69
# mse all (masked)patches: 0.37131574749946594
# all close: False
# Epoch: 70
# mse all (masked)patches: 0.3692561089992523
# all close: False
# Epoch: 71
# mse all (masked)patches: 0.37231284379959106
# all close: False
# Epoch: 72
# mse all (masked)patches: 0.3692416846752167
# all close: False
# Epoch: 73
# mse all (masked)patches: 0.3658464550971985
# all close: False
# Epoch: 74
# mse all (masked)patches: 0.3616153597831726
# all close: False
# Epoch: 75
# mse all (masked)patches: 0.36326998472213745
# all close: False
# Epoch: 76
# mse all (masked)patches: 0.36402761936187744
# all close: False
# Epoch: 77
# mse all (masked)patches: 0.360393226146698
# all close: False
# Epoch: 78
# mse all (masked)patches: 0.35911789536476135
# all close: False
# Epoch: 79
# mse all (masked)patches: 0.35737064480781555
# all close: False
# Epoch: 80
# mse all (masked)patches: 0.35747310519218445
# all close: False
# Epoch: 81
# mse all (masked)patches: 0.35953468084335327
# all close: False
# Epoch: 82
# mse all (masked)patches: 0.3535137176513672
# all close: False
# Epoch: 83
# mse all (masked)patches: 0.3557579219341278
# all close: False
# Epoch: 84
# mse all (masked)patches: 0.35036763548851013
# all close: False
# Epoch: 85
# mse all (masked)patches: 0.3562769591808319
# all close: False
# Epoch: 86
# mse all (masked)patches: 0.3531622886657715
# all close: False
# Epoch: 87
# mse all (masked)patches: 0.350694864988327
# all close: False
# Epoch: 88
# mse all (masked)patches: 0.3495137691497803
# all close: False
# Epoch: 89
# mse all (masked)patches: 0.34999799728393555
# all close: False
# Epoch: 90
# mse all (masked)patches: 0.3471413254737854
# all close: False
# Epoch: 91
# mse all (masked)patches: 0.3501530885696411
# all close: False
# Epoch: 92
# mse all (masked)patches: 0.3466203510761261
# all close: False
# Epoch: 93
# mse all (masked)patches: 0.34539794921875
# all close: False
# Epoch: 94
# mse all (masked)patches: 0.3447358012199402
# all close: False
# Epoch: 95
# mse all (masked)patches: 0.3444928526878357
# all close: False
# Epoch: 96
# mse all (masked)patches: 0.3378399908542633
# all close: False
# Epoch: 97
# mse all (masked)patches: 0.33988457918167114
# all close: False
# Epoch: 98
# mse all (masked)patches: 0.33967578411102295
# all close: False
# Epoch: 99
# mse all (masked)patches: 0.3340795040130615
# all close: False
# Epoch: 100
# mse all (masked)patches: 0.33676573634147644
# all close: False
# Epoch: 101
# mse all (masked)patches: 0.341340571641922
# all close: False
# Epoch: 102
# mse all (masked)patches: 0.3359587490558624
# all close: False
# Epoch: 103
# mse all (masked)patches: 0.33544522523880005
# all close: False
# Epoch: 104
# mse all (masked)patches: 0.33631110191345215
# all close: False
# Epoch: 105
# mse all (masked)patches: 0.3310392498970032
# all close: False
# Epoch: 106
# mse all (masked)patches: 0.32916343212127686
# all close: False
# Epoch: 107
# mse all (masked)patches: 0.3313950300216675
# all close: False
# Epoch: 108
# mse all (masked)patches: 0.3275112211704254
# all close: False
# Epoch: 109
# mse all (masked)patches: 0.328208863735199
# all close: False
# Epoch: 110
# mse all (masked)patches: 0.3283732831478119
# all close: False
# Epoch: 111
# mse all (masked)patches: 0.32583725452423096
# all close: False
# Epoch: 112
# mse all (masked)patches: 0.3259781301021576
# all close: False
# Epoch: 113
# mse all (masked)patches: 0.3275197148323059
# all close: False
# Epoch: 114
# mse all (masked)patches: 0.3233051300048828
# all close: False
# Epoch: 115
# mse all (masked)patches: 0.32540857791900635
# all close: False
# Epoch: 116
# mse all (masked)patches: 0.32420429587364197
# all close: False
# Epoch: 117
# mse all (masked)patches: 0.3209933638572693
# all close: False
# Epoch: 118
# mse all (masked)patches: 0.32052767276763916
# all close: False
# Epoch: 119
# mse all (masked)patches: 0.32158297300338745
# all close: False
# Epoch: 120
# mse all (masked)patches: 0.3205036520957947
# all close: False
# Epoch: 121
# mse all (masked)patches: 0.31658250093460083
# all close: False
# Epoch: 122
# mse all (masked)patches: 0.3199161887168884
# all close: False
# Epoch: 123
# mse all (masked)patches: 0.31490007042884827
# all close: False
# Epoch: 124
# mse all (masked)patches: 0.3171260952949524
# all close: False
# Epoch: 125
# mse all (masked)patches: 0.31704413890838623
# all close: False
# Epoch: 126
# mse all (masked)patches: 0.31392404437065125
# all close: False
# Epoch: 127
# mse all (masked)patches: 0.31409379839897156
# all close: False
# Epoch: 128
# mse all (masked)patches: 0.31212782859802246
# all close: False
# Epoch: 129
# mse all (masked)patches: 0.3109298050403595
# all close: False
# Epoch: 130
# mse all (masked)patches: 0.3101118505001068
# all close: False
# Epoch: 131
# mse all (masked)patches: 0.310153990983963
# all close: False
# Epoch: 132
# mse all (masked)patches: 0.30888432264328003
# all close: False
# Epoch: 133
# mse all (masked)patches: 0.30864042043685913
# all close: False
# Epoch: 134
# mse all (masked)patches: 0.3091789186000824
# all close: False
# Epoch: 135
# mse all (masked)patches: 0.30894166231155396
# all close: False
# Epoch: 136
# mse all (masked)patches: 0.30588555335998535
# all close: False
# Epoch: 137
# mse all (masked)patches: 0.3040779232978821
# all close: False
# Epoch: 138
# mse all (masked)patches: 0.30471694469451904
# all close: False
# Epoch: 139
# mse all (masked)patches: 0.30400457978248596
# all close: False
# Epoch: 140
# mse all (masked)patches: 0.3024696111679077
# all close: False
# Epoch: 141
# mse all (masked)patches: 0.30489659309387207
# all close: False
# Epoch: 142
# mse all (masked)patches: 0.2998306453227997
# all close: False
# Epoch: 143
# mse all (masked)patches: 0.3021726906299591
# all close: False
# Epoch: 144
# mse all (masked)patches: 0.30003443360328674
# all close: False
# Epoch: 145
# mse all (masked)patches: 0.29761502146720886
# all close: False
# Epoch: 146
# mse all (masked)patches: 0.29993805289268494
# all close: False
# Epoch: 147
# mse all (masked)patches: 0.2963225245475769
# all close: False
# Epoch: 148
# mse all (masked)patches: 0.2955719232559204
# all close: False
# Epoch: 149
# mse all (masked)patches: 0.29567739367485046
# all close: False
# Epoch: 150
# mse all (masked)patches: 0.2941613793373108
# all close: False
# Epoch: 151
# mse all (masked)patches: 0.29269787669181824
# all close: False
# Epoch: 152
# mse all (masked)patches: 0.2942391037940979
# all close: False
# Epoch: 153
# mse all (masked)patches: 0.2933633625507355
# all close: False
# Epoch: 154
# mse all (masked)patches: 0.2924988567829132
# all close: False
# Epoch: 155
# mse all (masked)patches: 0.28839007019996643
# all close: False
# Epoch: 156
# mse all (masked)patches: 0.2884889543056488
# all close: False
# Epoch: 157
# mse all (masked)patches: 0.28987547755241394
# all close: False
# Epoch: 158
# mse all (masked)patches: 0.28845348954200745
# all close: False
# Epoch: 159
# mse all (masked)patches: 0.2901272475719452
# all close: False
# Epoch: 160
# mse all (masked)patches: 0.28637996315956116
# all close: False
# Epoch: 161
# mse all (masked)patches: 0.2866813838481903
# all close: False
# Epoch: 162
# mse all (masked)patches: 0.28260594606399536
# all close: False
# Epoch: 163
# mse all (masked)patches: 0.28427502512931824
# all close: False
# Epoch: 164
# mse all (masked)patches: 0.28239667415618896
# all close: False
# Epoch: 165
# mse all (masked)patches: 0.28183290362358093
# all close: False
# Epoch: 166
# mse all (masked)patches: 0.28453654050827026
# all close: False
# Epoch: 167
# mse all (masked)patches: 0.280490905046463
# all close: False
# Epoch: 168
# mse all (masked)patches: 0.28043222427368164
# all close: False
# Epoch: 169
# mse all (masked)patches: 0.2798701226711273
# all close: False
# Epoch: 170
# mse all (masked)patches: 0.2791080176830292
# all close: False
# Epoch: 171
# mse all (masked)patches: 0.2776795029640198
# all close: False
# Epoch: 172
# mse all (masked)patches: 0.276224285364151
# all close: False
# Epoch: 173
# mse all (masked)patches: 0.27820903062820435
# all close: False
# Epoch: 174
# mse all (masked)patches: 0.2764035761356354
# all close: False
# Epoch: 175
# mse all (masked)patches: 0.27560532093048096
# all close: False
# Epoch: 176
# mse all (masked)patches: 0.27360156178474426
# all close: False
# Epoch: 177
# mse all (masked)patches: 0.2745380103588104
# all close: False
# Epoch: 178
# mse all (masked)patches: 0.2720503807067871
# all close: False
# Epoch: 179
# mse all (masked)patches: 0.2715320587158203
# all close: False
# Epoch: 180
# mse all (masked)patches: 0.2698350250720978
# all close: False
# Epoch: 181
# mse all (masked)patches: 0.27210381627082825
# all close: False
# Epoch: 182
# mse all (masked)patches: 0.26673632860183716
# all close: False
# Epoch: 183
# mse all (masked)patches: 0.27131569385528564
# all close: False
# Epoch: 184
# mse all (masked)patches: 0.26808488368988037
# all close: False
# Epoch: 185
# mse all (masked)patches: 0.265107661485672
# all close: False
# Epoch: 186
# mse all (masked)patches: 0.2662237286567688
# all close: False
# Epoch: 187
# mse all (masked)patches: 0.26633864641189575
# all close: False
# Epoch: 188
# mse all (masked)patches: 0.26401394605636597
# all close: False
# Epoch: 189
# mse all (masked)patches: 0.26543134450912476
# all close: False
# Epoch: 190
# mse all (masked)patches: 0.2626297175884247
# all close: False
# Epoch: 191
# mse all (masked)patches: 0.2644844055175781
# all close: False
# Epoch: 192
# mse all (masked)patches: 0.2616291046142578
# all close: False
# Epoch: 193
# mse all (masked)patches: 0.2635394036769867
# all close: False
# Epoch: 194
# mse all (masked)patches: 0.25985923409461975
# all close: False
# Epoch: 195
# mse all (masked)patches: 0.26254934072494507
# all close: False
# Epoch: 196
# mse all (masked)patches: 0.25890931487083435
# all close: False
# Epoch: 197
# mse all (masked)patches: 0.2587358355522156
# all close: False
# Epoch: 198
# mse all (masked)patches: 0.2572062313556671
# all close: False
# Epoch: 199
# mse all (masked)patches: 0.257618248462677
# all close: False
# Epoch: 200
# mse all (masked)patches: 0.25825899839401245
# all close: False
# Epoch: 201
# mse all (masked)patches: 0.25632673501968384
# all close: False
# Epoch: 202
# mse all (masked)patches: 0.2554510533809662
# all close: False
# Epoch: 203
# mse all (masked)patches: 0.2550792098045349
# all close: False
# Epoch: 204
# mse all (masked)patches: 0.25449344515800476
# all close: False
# Epoch: 205
# mse all (masked)patches: 0.2525787055492401
# all close: False
# Epoch: 206
# mse all (masked)patches: 0.2530257999897003
# all close: False
# Epoch: 207
# mse all (masked)patches: 0.25140026211738586
# all close: False
# Epoch: 208
# mse all (masked)patches: 0.2522294819355011
# all close: False
# Epoch: 209
# mse all (masked)patches: 0.2518361210823059
# all close: False
# Epoch: 210
# mse all (masked)patches: 0.2481805980205536
# all close: False
# Epoch: 211
# mse all (masked)patches: 0.249953031539917
# all close: False
# Epoch: 212
# mse all (masked)patches: 0.2491435557603836
# all close: False
# Epoch: 213
# mse all (masked)patches: 0.24714577198028564
# all close: False
# Epoch: 214
# mse all (masked)patches: 0.24819499254226685
# all close: False
# Epoch: 215
# mse all (masked)patches: 0.24645639955997467
# all close: False
# Epoch: 216
# mse all (masked)patches: 0.24574927985668182
# all close: False
# Epoch: 217
# mse all (masked)patches: 0.24573157727718353
# all close: False
# Epoch: 218
# mse all (masked)patches: 0.24382439255714417
# all close: False
# Epoch: 219
# mse all (masked)patches: 0.2434867024421692
# all close: False
# Epoch: 220
# mse all (masked)patches: 0.23965874314308167
# all close: False
# Epoch: 221
# mse all (masked)patches: 0.24277111887931824
# all close: False
# Epoch: 222
# mse all (masked)patches: 0.23618780076503754
# all close: False
# Epoch: 223
# mse all (masked)patches: 0.24042053520679474
# all close: False
# Epoch: 224
# mse all (masked)patches: 0.24045011401176453
# all close: False
# Epoch: 225
# mse all (masked)patches: 0.24043208360671997
# all close: False
# Epoch: 226
# mse all (masked)patches: 0.2375408560037613
# all close: False
# Epoch: 227
# mse all (masked)patches: 0.23611901700496674
# all close: False
# Epoch: 228
# mse all (masked)patches: 0.2345651537179947
# all close: False
# Epoch: 229
# mse all (masked)patches: 0.23547591269016266
# all close: False
# Epoch: 230
# mse all (masked)patches: 0.23614293336868286
# all close: False
# Epoch: 231
# mse all (masked)patches: 0.2355174869298935
# all close: False
# Epoch: 232
# mse all (masked)patches: 0.2358502745628357
# all close: False
# Epoch: 233
# mse all (masked)patches: 0.2334643006324768
# all close: False
# Epoch: 234
# mse all (masked)patches: 0.23673050105571747
# all close: False
# Epoch: 235
# mse all (masked)patches: 0.2330416440963745
# all close: False
# Epoch: 236
# mse all (masked)patches: 0.23415015637874603
# all close: False
# Epoch: 237
# mse all (masked)patches: 0.23280443251132965
# all close: False
# Epoch: 238
# mse all (masked)patches: 0.22827023267745972
# all close: False
# Epoch: 239
# mse all (masked)patches: 0.23061853647232056
# all close: False
# Epoch: 240
# mse all (masked)patches: 0.22957371175289154
# all close: False
# Epoch: 241
# mse all (masked)patches: 0.2321012020111084
# all close: False
# Epoch: 242
# mse all (masked)patches: 0.22992928326129913
# all close: False
# Epoch: 243
# mse all (masked)patches: 0.22791095077991486
# all close: False
# Epoch: 244
# mse all (masked)patches: 0.22477862238883972
# all close: False
# Epoch: 245
# mse all (masked)patches: 0.22605465352535248
# all close: False
# Epoch: 246
# mse all (masked)patches: 0.22593644261360168
# all close: False
# Epoch: 247
# mse all (masked)patches: 0.22475072741508484
# all close: False
# Epoch: 248
# mse all (masked)patches: 0.22602438926696777
# all close: False
# Epoch: 249
# mse all (masked)patches: 0.22308385372161865
# all close: False
# Epoch: 250
# mse all (masked)patches: 0.2229708731174469
# all close: False
# Epoch: 251
# mse all (masked)patches: 0.2240828424692154
# all close: False
# Epoch: 252
# mse all (masked)patches: 0.22352415323257446
# all close: False
# Epoch: 253
# mse all (masked)patches: 0.22007079422473907
# all close: False
# Epoch: 254
# mse all (masked)patches: 0.22122406959533691
# all close: False
# Epoch: 255
# mse all (masked)patches: 0.2184547781944275
# all close: False
# Epoch: 256
# mse all (masked)patches: 0.22276759147644043
# all close: False
# Epoch: 257
# mse all (masked)patches: 0.21762700378894806
# all close: False
# Epoch: 258
# mse all (masked)patches: 0.2160341590642929
# all close: False
# Epoch: 259
# mse all (masked)patches: 0.2197761982679367
# all close: False
# Epoch: 260
# mse all (masked)patches: 0.21719565987586975
# all close: False
# Epoch: 261
# mse all (masked)patches: 0.21798045933246613
# all close: False
# Epoch: 262
# mse all (masked)patches: 0.21806283295154572
# all close: False
# Epoch: 263
# mse all (masked)patches: 0.2172820270061493
# all close: False
# Epoch: 264
# mse all (masked)patches: 0.21539224684238434
# all close: False
# Epoch: 265
# mse all (masked)patches: 0.21446649730205536
# all close: False
# Epoch: 266
# mse all (masked)patches: 0.21293872594833374
# all close: False
# Epoch: 267
# mse all (masked)patches: 0.2133188396692276
# all close: False
# Epoch: 268
# mse all (masked)patches: 0.2141149640083313
# all close: False
# Epoch: 269
# mse all (masked)patches: 0.21090613305568695
# all close: False
# Epoch: 270
# mse all (masked)patches: 0.2142641395330429
# all close: False
# Epoch: 271
# mse all (masked)patches: 0.21021856367588043
# all close: False
# Epoch: 272
# mse all (masked)patches: 0.20962314307689667
# all close: False
# Epoch: 273
# mse all (masked)patches: 0.21067577600479126
# all close: False
# Epoch: 274
# mse all (masked)patches: 0.20955975353717804
# all close: False
# Epoch: 275
# mse all (masked)patches: 0.20779964327812195
# all close: False
# Epoch: 276
# mse all (masked)patches: 0.2103259265422821
# all close: False
# Epoch: 277
# mse all (masked)patches: 0.20751048624515533
# all close: False
# Epoch: 278
# mse all (masked)patches: 0.20659635961055756
# all close: False
# Epoch: 279
# mse all (masked)patches: 0.2041628509759903
# all close: False
# Epoch: 280
# mse all (masked)patches: 0.20603257417678833
# all close: False
# Epoch: 281
# mse all (masked)patches: 0.20411363244056702
# all close: False
# Epoch: 282
# mse all (masked)patches: 0.20439468324184418
# all close: False
# Epoch: 283
# mse all (masked)patches: 0.20158764719963074
# all close: False
# Epoch: 284
# mse all (masked)patches: 0.2051527500152588
# all close: False
# Epoch: 285
# mse all (masked)patches: 0.20052042603492737
# all close: False
# Epoch: 286
# mse all (masked)patches: 0.20052936673164368
# all close: False
# Epoch: 287
# mse all (masked)patches: 0.20292454957962036
# all close: False
# Epoch: 288
# mse all (masked)patches: 0.2035515159368515
# all close: False
# Epoch: 289
# mse all (masked)patches: 0.1998082399368286
# all close: False
# Epoch: 290
# mse all (masked)patches: 0.20015770196914673
# all close: False
# Epoch: 291
# mse all (masked)patches: 0.2000778317451477
# all close: False
# Epoch: 292
# mse all (masked)patches: 0.20026005804538727
# all close: False
# Epoch: 293
# mse all (masked)patches: 0.19917018711566925
# all close: False
# Epoch: 294
# mse all (masked)patches: 0.1974126249551773
# all close: False
# Epoch: 295
# mse all (masked)patches: 0.1967884749174118
# all close: False
# Epoch: 296
# mse all (masked)patches: 0.19741801917552948
# all close: False
# Epoch: 297
# mse all (masked)patches: 0.19583643972873688
# all close: False
# Epoch: 298
# mse all (masked)patches: 0.19258305430412292
# all close: False
# Epoch: 299
# mse all (masked)patches: 0.1959764063358307
# all close: False
# Epoch: 300
# mse all (masked)patches: 0.19474796950817108
# all close: False
# Epoch: 301
# mse all (masked)patches: 0.19437311589717865
# all close: False
# Epoch: 302
# mse all (masked)patches: 0.19449591636657715
# all close: False
# Epoch: 303
# mse all (masked)patches: 0.1924305260181427
# all close: False
# Epoch: 304
# mse all (masked)patches: 0.193630650639534
# all close: False
# Epoch: 305
# mse all (masked)patches: 0.19275258481502533
# all close: False
# Epoch: 306
# mse all (masked)patches: 0.19136542081832886
# all close: False
# Epoch: 307
# mse all (masked)patches: 0.1921001672744751
# all close: False
# Epoch: 308
# mse all (masked)patches: 0.18972621858119965
# all close: False
# Epoch: 309
# mse all (masked)patches: 0.1899198591709137
# all close: False
# Epoch: 310
# mse all (masked)patches: 0.1904064267873764
# all close: False
# Epoch: 311
# mse all (masked)patches: 0.1878795027732849
# all close: False
# Epoch: 312
# mse all (masked)patches: 0.18684259057044983
# all close: False
# Epoch: 313
# mse all (masked)patches: 0.1870085597038269
# all close: False
# Epoch: 314
# mse all (masked)patches: 0.18670868873596191
# all close: False
# Epoch: 315
# mse all (masked)patches: 0.18593160808086395
# all close: False
# Epoch: 316
# mse all (masked)patches: 0.18810544908046722
# all close: False
# Epoch: 317
# mse all (masked)patches: 0.18472230434417725
# all close: False
# Epoch: 318
# mse all (masked)patches: 0.18637049198150635
# all close: False
# Epoch: 319
# mse all (masked)patches: 0.18277740478515625
# all close: False
# Epoch: 320
# mse all (masked)patches: 0.18512406945228577
# all close: False
# Epoch: 321
# mse all (masked)patches: 0.1844872087240219
# all close: False
# Epoch: 322
# mse all (masked)patches: 0.18368856608867645
# all close: False
# Epoch: 323
# mse all (masked)patches: 0.18229883909225464
# all close: False
# Epoch: 324
# mse all (masked)patches: 0.18146046996116638
# all close: False
# Epoch: 325
# mse all (masked)patches: 0.18303067982196808
# all close: False
# Epoch: 326
# mse all (masked)patches: 0.17871560156345367
# all close: False
# Epoch: 327
# mse all (masked)patches: 0.18108922243118286
# all close: False
# Epoch: 328
# mse all (masked)patches: 0.17871402204036713
# all close: False
# Epoch: 329
# mse all (masked)patches: 0.17899896204471588
# all close: False
# Epoch: 330
# mse all (masked)patches: 0.17889565229415894
# all close: False
# Epoch: 331
# mse all (masked)patches: 0.18069641292095184
# all close: False
# Epoch: 332
# mse all (masked)patches: 0.17872728407382965
# all close: False
# Epoch: 333
# mse all (masked)patches: 0.177641823887825
# all close: False
# Epoch: 334
# mse all (masked)patches: 0.1798698455095291
# all close: False
# Epoch: 335
# mse all (masked)patches: 0.1803935468196869
# all close: False
# Epoch: 336
# mse all (masked)patches: 0.17593444883823395
# all close: False
# Epoch: 337
# mse all (masked)patches: 0.1772352159023285
# all close: False
# Epoch: 338
# mse all (masked)patches: 0.17667409777641296
# all close: False
# Epoch: 339
# mse all (masked)patches: 0.17527003586292267
# all close: False
# Epoch: 340
# mse all (masked)patches: 0.17527888715267181
# all close: False
# Epoch: 341
# mse all (masked)patches: 0.17721988260746002
# all close: False
# Epoch: 342
# mse all (masked)patches: 0.1766217052936554
# all close: False
# Epoch: 343
# mse all (masked)patches: 0.1735030561685562
# all close: False
# Epoch: 344
# mse all (masked)patches: 0.17463333904743195
# all close: False
# Epoch: 345
# mse all (masked)patches: 0.17537741363048553
# all close: False
# Epoch: 346
# mse all (masked)patches: 0.17133766412734985
# all close: False
# Epoch: 347
# mse all (masked)patches: 0.1734136939048767
# all close: False
# Epoch: 348
# mse all (masked)patches: 0.17063257098197937
# all close: False
# Epoch: 349
# mse all (masked)patches: 0.17304441332817078
# all close: False
# Epoch: 350
# mse all (masked)patches: 0.17235341668128967
# all close: False
# Epoch: 351
# mse all (masked)patches: 0.16857676208019257
# all close: False
# Epoch: 352
# mse all (masked)patches: 0.17048117518424988
# all close: False
# Epoch: 353
# mse all (masked)patches: 0.16963639855384827
# all close: False
# Epoch: 354
# mse all (masked)patches: 0.1676536351442337
# all close: False
# Epoch: 355
# mse all (masked)patches: 0.16569232940673828
# all close: False
# Epoch: 356
# mse all (masked)patches: 0.16925331950187683
# all close: False
# Epoch: 357
# mse all (masked)patches: 0.1656796932220459
# all close: False
# Epoch: 358
# mse all (masked)patches: 0.1671544462442398
# all close: False
# Epoch: 359
# mse all (masked)patches: 0.16817986965179443
# all close: False
# Epoch: 360
# mse all (masked)patches: 0.16662055253982544
# all close: False
# Epoch: 361
# mse all (masked)patches: 0.16821788251399994
# all close: False
# Epoch: 362
# mse all (masked)patches: 0.16330096125602722
# all close: False
# Epoch: 363
# mse all (masked)patches: 0.16533219814300537
# all close: False
# Epoch: 364
# mse all (masked)patches: 0.16301314532756805
# all close: False
# Epoch: 365
# mse all (masked)patches: 0.1645638644695282
# all close: False
# Epoch: 366
# mse all (masked)patches: 0.15985430777072906
# all close: False
# Epoch: 367
# mse all (masked)patches: 0.16403338313102722
# all close: False
# Epoch: 368
# mse all (masked)patches: 0.16281050443649292
# all close: False
# Epoch: 369
# mse all (masked)patches: 0.1644110381603241
# all close: False
# Epoch: 370
# mse all (masked)patches: 0.16308966279029846
# all close: False
# Epoch: 371
# mse all (masked)patches: 0.16312448680400848
# all close: False
# Epoch: 372
# mse all (masked)patches: 0.1601535975933075
# all close: False
# Epoch: 373
# mse all (masked)patches: 0.16082604229450226
# all close: False
# Epoch: 374
# mse all (masked)patches: 0.15884967148303986
# all close: False
# Epoch: 375
# mse all (masked)patches: 0.16014744341373444
# all close: False
# Epoch: 376
# mse all (masked)patches: 0.1594305783510208
# all close: False
# Epoch: 377
# mse all (masked)patches: 0.16018524765968323
# all close: False
# Epoch: 378
# mse all (masked)patches: 0.15820810198783875
# all close: False
# Epoch: 379
# mse all (masked)patches: 0.1586911380290985
# all close: False
# Epoch: 380
# mse all (masked)patches: 0.15951621532440186
# all close: False
# Epoch: 381
# mse all (masked)patches: 0.1617138832807541
# all close: False
# Epoch: 382
# mse all (masked)patches: 0.16141188144683838
# all close: False
# Epoch: 383
# mse all (masked)patches: 0.15915390849113464
# all close: False
# Epoch: 384
# mse all (masked)patches: 0.1574249565601349
# all close: False
# Epoch: 385
# mse all (masked)patches: 0.15592968463897705
# all close: False
# Epoch: 386
# mse all (masked)patches: 0.15595334768295288
# all close: False
# Epoch: 387
# mse all (masked)patches: 0.15613655745983124
# all close: False
# Epoch: 388
# mse all (masked)patches: 0.1565369814634323
# all close: False
# Epoch: 389
# mse all (masked)patches: 0.15858714282512665
# all close: False
# Epoch: 390
# mse all (masked)patches: 0.15830577909946442
# all close: False
# Epoch: 391
# mse all (masked)patches: 0.15374234318733215
# all close: False
# Epoch: 392
# mse all (masked)patches: 0.15258701145648956
# all close: False
# Epoch: 393
# mse all (masked)patches: 0.153436079621315
# all close: False
# Epoch: 394
# mse all (masked)patches: 0.15208719670772552
# all close: False
# Epoch: 395
# mse all (masked)patches: 0.1536085307598114
# all close: False
# Epoch: 396
# mse all (masked)patches: 0.15363788604736328
# all close: False
# Epoch: 397
# mse all (masked)patches: 0.15155717730522156
# all close: False
# Epoch: 398
# mse all (masked)patches: 0.1519624888896942
# all close: False
# Epoch: 399
# mse all (masked)patches: 0.15399347245693207
# all close: False
# Epoch: 400
# mse all (masked)patches: 0.1544983983039856
# all close: False
# Epoch: 401
# mse all (masked)patches: 0.15068629384040833
# all close: False
# Epoch: 402
# mse all (masked)patches: 0.1531050205230713
# all close: False
# Epoch: 403
# mse all (masked)patches: 0.15287351608276367
# all close: False
# Epoch: 404
# mse all (masked)patches: 0.1504346877336502
# all close: False
# Epoch: 405
# mse all (masked)patches: 0.15082795917987823
# all close: False
# Epoch: 406
# mse all (masked)patches: 0.1495073437690735
# all close: False
# Epoch: 407
# mse all (masked)patches: 0.14964789152145386
# all close: False
# Epoch: 408
# mse all (masked)patches: 0.1495531052350998
# all close: False
# Epoch: 409
# mse all (masked)patches: 0.1492619663476944
# all close: False
# Epoch: 410
# mse all (masked)patches: 0.14510716497898102
# all close: False
# Epoch: 411
# mse all (masked)patches: 0.1494055539369583
# all close: False
# Epoch: 412
# mse all (masked)patches: 0.1504059135913849
# all close: False
# Epoch: 413
# mse all (masked)patches: 0.15041787922382355
# all close: False
# Epoch: 414
# mse all (masked)patches: 0.14716137945652008
# all close: False
# Epoch: 415
# mse all (masked)patches: 0.14797700941562653
# all close: False
# Epoch: 416
# mse all (masked)patches: 0.14439210295677185
# all close: False
# Epoch: 417
# mse all (masked)patches: 0.14931249618530273
# all close: False
# Epoch: 418
# mse all (masked)patches: 0.14582696557044983
# all close: False
# Epoch: 419
# mse all (masked)patches: 0.146165668964386
# all close: False
# Epoch: 420
# mse all (masked)patches: 0.15011052787303925
# all close: False
# Epoch: 421
# mse all (masked)patches: 0.14858442544937134
# all close: False
# Epoch: 422
# mse all (masked)patches: 0.14777231216430664
# all close: False
# Epoch: 423
# mse all (masked)patches: 0.14366279542446136
# all close: False
# Epoch: 424
# mse all (masked)patches: 0.14552049338817596
# all close: False
# Epoch: 425
# mse all (masked)patches: 0.14437632262706757
# all close: False
# Epoch: 426
# mse all (masked)patches: 0.14777760207653046
# all close: False
# Epoch: 427
# mse all (masked)patches: 0.1407472938299179
# all close: False
# Epoch: 428
# mse all (masked)patches: 0.14378581941127777
# all close: False
# Epoch: 429
# mse all (masked)patches: 0.1426994800567627
# all close: False
# Epoch: 430
# mse all (masked)patches: 0.14482271671295166
# all close: False
# Epoch: 431
# mse all (masked)patches: 0.141408309340477
# all close: False
# Epoch: 432
# mse all (masked)patches: 0.14365342259407043
# all close: False
# Epoch: 433
# mse all (masked)patches: 0.14335845410823822
# all close: False
# Epoch: 434
# mse all (masked)patches: 0.14182068407535553
# all close: False
# Epoch: 435
# mse all (masked)patches: 0.14148657023906708
# all close: False
# Epoch: 436
# mse all (masked)patches: 0.1403057873249054
# all close: False
# Epoch: 437
# mse all (masked)patches: 0.14221414923667908
# all close: False
# Epoch: 438
# mse all (masked)patches: 0.14123941957950592
# all close: False
# Epoch: 439
# mse all (masked)patches: 0.1404017210006714
# all close: False
# Epoch: 440
# mse all (masked)patches: 0.14133258163928986
# all close: False
# Epoch: 441
# mse all (masked)patches: 0.13713732361793518
# all close: False
# Epoch: 442
# mse all (masked)patches: 0.13982391357421875
# all close: False
# Epoch: 443
# mse all (masked)patches: 0.13898701965808868
# all close: False
# Epoch: 444
# mse all (masked)patches: 0.13719654083251953
# all close: False
# Epoch: 445
# mse all (masked)patches: 0.13682669401168823
# all close: False
# Epoch: 446
# mse all (masked)patches: 0.13872483372688293
# all close: False
# Epoch: 447
# mse all (masked)patches: 0.13625766336917877
# all close: False
# Epoch: 448
# mse all (masked)patches: 0.13672131299972534
# all close: False
# Epoch: 449
# mse all (masked)patches: 0.13810251653194427
# all close: False
# Epoch: 450
# mse all (masked)patches: 0.13754905760288239
# all close: False
# Epoch: 451
# mse all (masked)patches: 0.13507643342018127
# all close: False
# Epoch: 452
# mse all (masked)patches: 0.13871072232723236
# all close: False
# Epoch: 453
# mse all (masked)patches: 0.13639764487743378
# all close: False
# Epoch: 454
# mse all (masked)patches: 0.13928526639938354
# all close: False
# Epoch: 455
# mse all (masked)patches: 0.1358065903186798
# all close: False
# Epoch: 456
# mse all (masked)patches: 0.13758599758148193
# all close: False
# Epoch: 457
# mse all (masked)patches: 0.1365167796611786
# all close: False
# Epoch: 458
# mse all (masked)patches: 0.13548552989959717
# all close: False
# Epoch: 459
# mse all (masked)patches: 0.13743886351585388
# all close: False
# Epoch: 460
# mse all (masked)patches: 0.13499228656291962
# all close: False
# Epoch: 461
# mse all (masked)patches: 0.13448642194271088
# all close: False
# Epoch: 462
# mse all (masked)patches: 0.13534100353717804
# all close: False
# Epoch: 463
# mse all (masked)patches: 0.13420172035694122
# all close: False
# Epoch: 464
# mse all (masked)patches: 0.13411398231983185
# all close: False
# Epoch: 465
# mse all (masked)patches: 0.13194377720355988
# all close: False
# Epoch: 466
# mse all (masked)patches: 0.13043241202831268
# all close: False
# Epoch: 467
# mse all (masked)patches: 0.13096275925636292
# all close: False
# Epoch: 468
# mse all (masked)patches: 0.1328447312116623
# all close: False
# Epoch: 469
# mse all (masked)patches: 0.13172969222068787
# all close: False
# Epoch: 470
# mse all (masked)patches: 0.13138432800769806
# all close: False
# Epoch: 471
# mse all (masked)patches: 0.13309703767299652
# all close: False
# Epoch: 472
# mse all (masked)patches: 0.13356514275074005
# all close: False
# Epoch: 473
# mse all (masked)patches: 0.1317010372877121
# all close: False
# Epoch: 474
# mse all (masked)patches: 0.12989407777786255
# all close: False
# Epoch: 475
# mse all (masked)patches: 0.13633783161640167
# all close: False
# Epoch: 476
# mse all (masked)patches: 0.13457632064819336
# all close: False
# Epoch: 477
# mse all (masked)patches: 0.1314258873462677
# all close: False
# Epoch: 478
# mse all (masked)patches: 0.13205355405807495
# all close: False
# Epoch: 479
# mse all (masked)patches: 0.12983731925487518
# all close: False
# Epoch: 480
# mse all (masked)patches: 0.13015390932559967
# all close: False
# Epoch: 481
# mse all (masked)patches: 0.1316300630569458
# all close: False
# Epoch: 482
# mse all (masked)patches: 0.1301528811454773
# all close: False
# Epoch: 483
# mse all (masked)patches: 0.1307813674211502
# all close: False
# Epoch: 484
# mse all (masked)patches: 0.12998270988464355
# all close: False
# Epoch: 485
# mse all (masked)patches: 0.1304738074541092
# all close: False
# Epoch: 486
# mse all (masked)patches: 0.13031038641929626
# all close: False
# Epoch: 487
# mse all (masked)patches: 0.1296563744544983
# all close: False
# Epoch: 488
# mse all (masked)patches: 0.1276608407497406
# all close: False
# Epoch: 489
# mse all (masked)patches: 0.12839269638061523
# all close: False
# Epoch: 490
# mse all (masked)patches: 0.1276729553937912
# all close: False
# Epoch: 491
# mse all (masked)patches: 0.1270432472229004
# all close: False
# Epoch: 492
# mse all (masked)patches: 0.13085469603538513
# all close: False
# Epoch: 493
# mse all (masked)patches: 0.12788933515548706
# all close: False
# Epoch: 494
# mse all (masked)patches: 0.12797091901302338
# all close: False
# Epoch: 495
# mse all (masked)patches: 0.1272878348827362
# all close: False
# Epoch: 496
# mse all (masked)patches: 0.12742212414741516
# all close: False
# Epoch: 497
# mse all (masked)patches: 0.12788815796375275
# all close: False
# Epoch: 498
# mse all (masked)patches: 0.12777945399284363
# all close: False
# Epoch: 499
# mse all (masked)patches: 0.12607300281524658
# all close: False
# Epoch: 500
# mse all (masked)patches: 0.12784993648529053
# all close: False
# Epoch: 501
# mse all (masked)patches: 0.12572559714317322
# all close: False
# Epoch: 502
# mse all (masked)patches: 0.1242060735821724
# all close: False
# Epoch: 503
# mse all (masked)patches: 0.12741778790950775
# all close: False
# Epoch: 504
# mse all (masked)patches: 0.12752658128738403
# all close: False
# Epoch: 505
# mse all (masked)patches: 0.12679916620254517
# all close: False
# Epoch: 506
# mse all (masked)patches: 0.12895876169204712
# all close: False
# Epoch: 507
# mse all (masked)patches: 0.1272534728050232
# all close: False
# Epoch: 508
# mse all (masked)patches: 0.12480983138084412
# all close: False
# Epoch: 509
# mse all (masked)patches: 0.12211764603853226
# all close: False
# Epoch: 510
# mse all (masked)patches: 0.1268579661846161
# all close: False
# Epoch: 511
# mse all (masked)patches: 0.12412561476230621
# all close: False
# Epoch: 512
# mse all (masked)patches: 0.12889128923416138
# all close: False
# Epoch: 513
# mse all (masked)patches: 0.12398357689380646
# all close: False
# Epoch: 514
# mse all (masked)patches: 0.1231202632188797
# all close: False
# Epoch: 515
# mse all (masked)patches: 0.12421806156635284
# all close: False
# Epoch: 516
# mse all (masked)patches: 0.12002882361412048
# all close: False
# Epoch: 517
# mse all (masked)patches: 0.12353330850601196
# all close: False
# Epoch: 518
# mse all (masked)patches: 0.1185324415564537
# all close: False
# Epoch: 519
# mse all (masked)patches: 0.12392662465572357
# all close: False
# Epoch: 520
# mse all (masked)patches: 0.12476374208927155
# all close: False
# Epoch: 521
# mse all (masked)patches: 0.1257869452238083
# all close: False
# Epoch: 522
# mse all (masked)patches: 0.12083616107702255
# all close: False
# Epoch: 523
# mse all (masked)patches: 0.11950559914112091
# all close: False
# Epoch: 524
# mse all (masked)patches: 0.12219163775444031
# all close: False
# Epoch: 525
# mse all (masked)patches: 0.11953600496053696
# all close: False
# Epoch: 526
# mse all (masked)patches: 0.12391060590744019
# all close: False
# Epoch: 527
# mse all (masked)patches: 0.12174195796251297
# all close: False
# Epoch: 528
# mse all (masked)patches: 0.11999081820249557
# all close: False
# Epoch: 529
# mse all (masked)patches: 0.12189746648073196
# all close: False
# Epoch: 530
# mse all (masked)patches: 0.11728045344352722
# all close: False
# Epoch: 531
# mse all (masked)patches: 0.12067574262619019
# all close: False
# Epoch: 532
# mse all (masked)patches: 0.12220288068056107
# all close: False
# Epoch: 533
# mse all (masked)patches: 0.1206214502453804
# all close: False
# Epoch: 534
# mse all (masked)patches: 0.11973509192466736
# all close: False
# Epoch: 535
# mse all (masked)patches: 0.11813294887542725
# all close: False
# Epoch: 536
# mse all (masked)patches: 0.11756937205791473
# all close: False
# Epoch: 537
# mse all (masked)patches: 0.11843779683113098
# all close: False
# Epoch: 538
# mse all (masked)patches: 0.12112278491258621
# all close: False
# Epoch: 539
# mse all (masked)patches: 0.11598221212625504
# all close: False
# Epoch: 540
# mse all (masked)patches: 0.1210426539182663
# all close: False
# Epoch: 541
# mse all (masked)patches: 0.11932966858148575
# all close: False
# Epoch: 542
# mse all (masked)patches: 0.12015273422002792
# all close: False
# Epoch: 543
# mse all (masked)patches: 0.11606563627719879
# all close: False
# Epoch: 544
# mse all (masked)patches: 0.11996698379516602
# all close: False
# Epoch: 545
# mse all (masked)patches: 0.1179991364479065
# all close: False
# Epoch: 546
# mse all (masked)patches: 0.1178082525730133
# all close: False
# Epoch: 547
# mse all (masked)patches: 0.12009771913290024
# all close: False
# Epoch: 548
# mse all (masked)patches: 0.11814350634813309
# all close: False
# Epoch: 549
# mse all (masked)patches: 0.12229685485363007
# all close: False
# Epoch: 550
# mse all (masked)patches: 0.11880980432033539
# all close: False
# Epoch: 551
# mse all (masked)patches: 0.1182316318154335
# all close: False
# Epoch: 552
# mse all (masked)patches: 0.11685602366924286
# all close: False
# Epoch: 553
# mse all (masked)patches: 0.11760351061820984
# all close: False
# Epoch: 554
# mse all (masked)patches: 0.11844826489686966
# all close: False
# Epoch: 555
# mse all (masked)patches: 0.11370519548654556
# all close: False
# Epoch: 556
# mse all (masked)patches: 0.11589039862155914
# all close: False
# Epoch: 557
# mse all (masked)patches: 0.12059143930673599
# all close: False
# Epoch: 558
# mse all (masked)patches: 0.11984391510486603
# all close: False
# Epoch: 559
# mse all (masked)patches: 0.11792819947004318
# all close: False
# Epoch: 560
# mse all (masked)patches: 0.11648073047399521
# all close: False
# Epoch: 561
# mse all (masked)patches: 0.11758162081241608
# all close: False
# Epoch: 562
# mse all (masked)patches: 0.11550749838352203
# all close: False
# Epoch: 563
# mse all (masked)patches: 0.11833324283361435
# all close: False
# Epoch: 564
# mse all (masked)patches: 0.11494117230176926
# all close: False
# Epoch: 565
# mse all (masked)patches: 0.11831259727478027
# all close: False
# Epoch: 566
# mse all (masked)patches: 0.11464731395244598
# all close: False
# Epoch: 567
# mse all (masked)patches: 0.11608855426311493
# all close: False
# Epoch: 568
# mse all (masked)patches: 0.1174580305814743
# all close: False
# Epoch: 569
# mse all (masked)patches: 0.1161249503493309
# all close: False
# Epoch: 570
# mse all (masked)patches: 0.11594723165035248
# all close: False
# Epoch: 571
# mse all (masked)patches: 0.11275391280651093
# all close: False
# Epoch: 572
# mse all (masked)patches: 0.11697123944759369
# all close: False
# Epoch: 573
# mse all (masked)patches: 0.11647047847509384
# all close: False
# Epoch: 574
# mse all (masked)patches: 0.11426140367984772
# all close: False
# Epoch: 575
# mse all (masked)patches: 0.11621502041816711
# all close: False
# Epoch: 576
# mse all (masked)patches: 0.1123330220580101
# all close: False
# Epoch: 577
# mse all (masked)patches: 0.11602414399385452
# all close: False
# Epoch: 578
# mse all (masked)patches: 0.11363827437162399
# all close: False
# Epoch: 579
# mse all (masked)patches: 0.11372682452201843
# all close: False
# Epoch: 580
# mse all (masked)patches: 0.11309412121772766
# all close: False
# Epoch: 581
# mse all (masked)patches: 0.11471862345933914
# all close: False
# Epoch: 582
# mse all (masked)patches: 0.11301899701356888
# all close: False
# Epoch: 583
# mse all (masked)patches: 0.11291934549808502
# all close: False
# Epoch: 584
# mse all (masked)patches: 0.11469724029302597
# all close: False
# Epoch: 585
# mse all (masked)patches: 0.11001851409673691
# all close: False
# Epoch: 586
# mse all (masked)patches: 0.11143893003463745
# all close: False
# Epoch: 587
# mse all (masked)patches: 0.11624261736869812
# all close: False
# Epoch: 588
# mse all (masked)patches: 0.11659181118011475
# all close: False
# Epoch: 589
# mse all (masked)patches: 0.11340466886758804
# all close: False
# Epoch: 590
# mse all (masked)patches: 0.11221271753311157
# all close: False
# Epoch: 591
# mse all (masked)patches: 0.11272148787975311
# all close: False
# Epoch: 592
# mse all (masked)patches: 0.10986429452896118
# all close: False
# Epoch: 593
# mse all (masked)patches: 0.11457828432321548
# all close: False
# Epoch: 594
# mse all (masked)patches: 0.10986905544996262
# all close: False
# Epoch: 595
# mse all (masked)patches: 0.11203795671463013
# all close: False
# Epoch: 596
# mse all (masked)patches: 0.11133573949337006
# all close: False
# Epoch: 597
# mse all (masked)patches: 0.11210069060325623
# all close: False
# Epoch: 598
# mse all (masked)patches: 0.11036426573991776
# all close: False
# Epoch: 599
# mse all (masked)patches: 0.10923624038696289
# all close: False
# Epoch: 600
# mse all (masked)patches: 0.11131644248962402
# all close: False
# Epoch: 601
# mse all (masked)patches: 0.10985395312309265
# all close: False
# Epoch: 602
# mse all (masked)patches: 0.11233547329902649
# all close: False
# Epoch: 603
# mse all (masked)patches: 0.10869190096855164
# all close: False
# Epoch: 604
# mse all (masked)patches: 0.11187172681093216
# all close: False
# Epoch: 605
# mse all (masked)patches: 0.1101110428571701
# all close: False
# Epoch: 606
# mse all (masked)patches: 0.1109526976943016
# all close: False
# Epoch: 607
# mse all (masked)patches: 0.11006004363298416
# all close: False
# Epoch: 608
# mse all (masked)patches: 0.10813377797603607
# all close: False
# Epoch: 609
# mse all (masked)patches: 0.10832244902849197
# all close: False
# Epoch: 610
# mse all (masked)patches: 0.1127583235502243
# all close: False
# Epoch: 611
# mse all (masked)patches: 0.10993383824825287
# all close: False
# Epoch: 612
# mse all (masked)patches: 0.11015652120113373
# all close: False
# Epoch: 613
# mse all (masked)patches: 0.10964273661375046
# all close: False
# Epoch: 614
# mse all (masked)patches: 0.10888689756393433
# all close: False
# Epoch: 615
# mse all (masked)patches: 0.10786136984825134
# all close: False
# Epoch: 616
# mse all (masked)patches: 0.10922995954751968
# all close: False
# Epoch: 617
# mse all (masked)patches: 0.10940086841583252
# all close: False
# Epoch: 618
# mse all (masked)patches: 0.10614576935768127
# all close: False
# Epoch: 619
# mse all (masked)patches: 0.10953469574451447
# all close: False
# Epoch: 620
# mse all (masked)patches: 0.1106535941362381
# all close: False
# Epoch: 621
# mse all (masked)patches: 0.10728655010461807
# all close: False
# Epoch: 622
# mse all (masked)patches: 0.10688699781894684
# all close: False
# Epoch: 623
# mse all (masked)patches: 0.11062709987163544
# all close: False
# Epoch: 624
# mse all (masked)patches: 0.10696343332529068
# all close: False
# Epoch: 625
# mse all (masked)patches: 0.10603994131088257
# all close: False
# Epoch: 626
# mse all (masked)patches: 0.10683369636535645
# all close: False
# Epoch: 627
# mse all (masked)patches: 0.10717528313398361
# all close: False
# Epoch: 628
# mse all (masked)patches: 0.10533041507005692
# all close: False
# Epoch: 629
# mse all (masked)patches: 0.10643548518419266
# all close: False
# Epoch: 630
# mse all (masked)patches: 0.10533233731985092
# all close: False
# Epoch: 631
# mse all (masked)patches: 0.10604355484247208
# all close: False
# Epoch: 632
# mse all (masked)patches: 0.10931476950645447
# all close: False
# Epoch: 633
# mse all (masked)patches: 0.11097854375839233
# all close: False
# Epoch: 634
# mse all (masked)patches: 0.10868487507104874
# all close: False
# Epoch: 635
# mse all (masked)patches: 0.10941388458013535
# all close: False
# Epoch: 636
# mse all (masked)patches: 0.10730218887329102
# all close: False
# Epoch: 637
# mse all (masked)patches: 0.10774712264537811
# all close: False
# Epoch: 638
# mse all (masked)patches: 0.10215045511722565
# all close: False
# Epoch: 639
# mse all (masked)patches: 0.10208047926425934
# all close: False
# Epoch: 640
# mse all (masked)patches: 0.10951494425535202
# all close: False
# Epoch: 641
# mse all (masked)patches: 0.10837696492671967
# all close: False
# Epoch: 642
# mse all (masked)patches: 0.1053084135055542
# all close: False
# Epoch: 643
# ...
# all close: False
# Epoch: 788
# mse all (masked)patches: 0.10044638812541962
# all close: False
# Epoch: 789
# mse all (masked)patches: 0.1003890261054039
# all close: False
# Epoch: 790
# mse all (masked)patches: 0.09983132779598236
# all close: False
# Epoch: 791
# mse all (masked)patches: 0.09772460162639618
# all close: False
# Epoch: 792
# mse all (masked)patches: 0.09736625850200653
# all close: False
# Epoch: 793
# mse all (masked)patches: 0.09691941738128662
# all close: False
# Epoch: 794
# mse all (masked)patches: 0.09899075329303741
# all close: False
# Epoch: 795
# mse all (masked)patches: 0.09610658138990402
# all close: False
# Epoch: 796
# mse all (masked)patches: 0.10015702247619629
# all close: False
# Epoch: 797
# mse all (masked)patches: 0.09837634116411209
# all close: False
# Epoch: 798
# mse all (masked)patches: 0.09807346016168594
# all close: False
# Epoch: 799
# mse all (masked)patches: 0.09596104174852371
# all close: False
# Epoch: 800
# mse all (masked)patches: 0.09914889186620712
# all close: False
# Epoch: 801
# mse all (masked)patches: 0.09762076288461685
# all close: False
# Epoch: 802
# mse all (masked)patches: 0.09721603989601135
# all close: False
# Epoch: 803
# mse all (masked)patches: 0.09889385104179382
# all close: False
# Epoch: 804
# mse all (masked)patches: 0.09893172979354858
# all close: False
# Epoch: 805
# mse all (masked)patches: 0.10057180374860764
# all close: False
# Epoch: 806
# mse all (masked)patches: 0.09703858941793442
# all close: False
# Epoch: 807
# mse all (masked)patches: 0.09787409752607346
# all close: False
# Epoch: 808
# mse all (masked)patches: 0.09860978275537491
# all close: False
# Epoch: 809
# mse all (masked)patches: 0.09855221211910248
# all close: False
# Epoch: 810
# mse all (masked)patches: 0.09809053689241409
# all close: False
# Epoch: 811
# mse all (masked)patches: 0.10119132697582245
# all close: False
# Epoch: 812
# mse all (masked)patches: 0.09819986671209335
# all close: False
# Epoch: 813
# mse all (masked)patches: 0.09348303079605103
# all close: False
# Epoch: 814
# mse all (masked)patches: 0.09411467611789703
# all close: False
# Epoch: 815
# mse all (masked)patches: 0.10017647594213486
# all close: False
# Epoch: 816
# mse all (masked)patches: 0.09753809124231339
# all close: False
# Epoch: 817
# mse all (masked)patches: 0.09287548810243607
# all close: False
# Epoch: 818
# mse all (masked)patches: 0.09657000005245209
# all close: False
# Epoch: 819
# mse all (masked)patches: 0.09407813847064972
# all close: False
# Epoch: 820
# mse all (masked)patches: 0.09821564704179764
# all close: False
# Epoch: 821
# mse all (masked)patches: 0.09616279602050781
# all close: False
# Epoch: 822
# mse all (masked)patches: 0.09965988248586655
# all close: False
# Epoch: 823
# mse all (masked)patches: 0.09720739722251892
# all close: False
# Epoch: 824
# mse all (masked)patches: 0.09753093123435974
# all close: False
# Epoch: 825
# mse all (masked)patches: 0.09688473492860794
# all close: False
# Epoch: 826
# mse all (masked)patches: 0.09628358483314514
# all close: False
# Epoch: 827
# mse all (masked)patches: 0.09937013685703278
# all close: False
# Epoch: 828
# mse all (masked)patches: 0.10002122819423676
# all close: False
# Epoch: 829
# mse all (masked)patches: 0.10067015886306763
# all close: False
# Epoch: 830
# mse all (masked)patches: 0.09682142734527588
# all close: False
# Epoch: 831
# mse all (masked)patches: 0.1016412079334259
# all close: False
# Epoch: 832
# mse all (masked)patches: 0.09232959151268005
# all close: False
# Epoch: 833
# mse all (masked)patches: 0.09402312338352203
# all close: False
# Epoch: 834
# mse all (masked)patches: 0.09439955651760101
# all close: False
# Epoch: 835
# mse all (masked)patches: 0.0970379039645195
# all close: False
# Epoch: 836
# mse all (masked)patches: 0.09702468663454056
# all close: False
# Epoch: 837
# mse all (masked)patches: 0.09816596657037735
# all close: False
# Epoch: 838
# mse all (masked)patches: 0.09586530178785324
# all close: False
# Epoch: 839
# mse all (masked)patches: 0.09439650923013687
# all close: False
# Epoch: 840
# mse all (masked)patches: 0.10130441188812256
# all close: False
# Epoch: 841
# mse all (masked)patches: 0.09765375405550003
# all close: False
# Epoch: 842
# mse all (masked)patches: 0.09588155150413513
# all close: False
# Epoch: 843
# mse all (masked)patches: 0.09367211908102036
# all close: False
# Epoch: 844
# mse all (masked)patches: 0.09756498038768768
# all close: False
# Epoch: 845
# mse all (masked)patches: 0.09591668099164963
# all close: False
# Epoch: 846
# mse all (masked)patches: 0.09799464792013168
# all close: False
# Epoch: 847
# mse all (masked)patches: 0.09724241495132446
# all close: False
# Epoch: 848
# mse all (masked)patches: 0.0989973396062851
# all close: False
# Epoch: 849
# mse all (masked)patches: 0.09526809304952621
# all close: False
# Epoch: 850
# mse all (masked)patches: 0.09801219403743744
# all close: False
# Epoch: 851
# mse all (masked)patches: 0.09456084668636322
# all close: False
# Epoch: 852
# mse all (masked)patches: 0.09519342333078384
# all close: False
# Epoch: 853
# mse all (masked)patches: 0.09794931858778
# all close: False
# Epoch: 854
# mse all (masked)patches: 0.09551528096199036
# all close: False
# Epoch: 855
# mse all (masked)patches: 0.09876559674739838
# all close: False
# Epoch: 856
# mse all (masked)patches: 0.09302815049886703
# all close: False
# Epoch: 857
# mse all (masked)patches: 0.09846431761980057
# all close: False
# Epoch: 858
# mse all (masked)patches: 0.0961185023188591
# all close: False
# Epoch: 859
# mse all (masked)patches: 0.0945085659623146
# all close: False
# Epoch: 860
# mse all (masked)patches: 0.09513869136571884
# all close: False
# Epoch: 861
# mse all (masked)patches: 0.09575973451137543
# all close: False
# Epoch: 862
# mse all (masked)patches: 0.10016004741191864
# all close: False
# Epoch: 863
# mse all (masked)patches: 0.09397797286510468
# all close: False
# Epoch: 864
# mse all (masked)patches: 0.09005110710859299
# all close: False
# Epoch: 865
# mse all (masked)patches: 0.0950833410024643
# all close: False
# Epoch: 866
# mse all (masked)patches: 0.09479659050703049
# all close: False
# Epoch: 867
# mse all (masked)patches: 0.0944681316614151
# all close: False
# Epoch: 868
# mse all (masked)patches: 0.09741954505443573
# all close: False
# Epoch: 869
# mse all (masked)patches: 0.09592881053686142
# all close: False
# Epoch: 870
# mse all (masked)patches: 0.09653542190790176
# all close: False
# Epoch: 871
# mse all (masked)patches: 0.09530586749315262
# all close: False
# Epoch: 872
# mse all (masked)patches: 0.09608128666877747
# all close: False
# Epoch: 873
# mse all (masked)patches: 0.09537798911333084
# all close: False
# Epoch: 874
# mse all (masked)patches: 0.09470368176698685
# all close: False
# Epoch: 875
# mse all (masked)patches: 0.09498431533575058
# all close: False
# Epoch: 876
# mse all (masked)patches: 0.09340853989124298
# all close: False
# Epoch: 877
# mse all (masked)patches: 0.09814812988042831
# all close: False
# Epoch: 878
# mse all (masked)patches: 0.09476280957460403
# all close: False
# Epoch: 879
# mse all (masked)patches: 0.09516038745641708
# all close: False
# Epoch: 880
# mse all (masked)patches: 0.09642858803272247
# all close: False
# Epoch: 881
# mse all (masked)patches: 0.0955403596162796
# all close: False
# Epoch: 882
# mse all (masked)patches: 0.09563327580690384
# all close: False
# Epoch: 883
# mse all (masked)patches: 0.09560510516166687
# all close: False
# Epoch: 884
# mse all (masked)patches: 0.09436355531215668
# all close: False
# Epoch: 885
# mse all (masked)patches: 0.09584546089172363
# all close: False
# Epoch: 886
# mse all (masked)patches: 0.09664859622716904
# all close: False
# Epoch: 887
# mse all (masked)patches: 0.09555423259735107
# all close: False
# Epoch: 888
# mse all (masked)patches: 0.09463825821876526
# all close: False
# Epoch: 889
# mse all (masked)patches: 0.09711672365665436
# all close: False
# Epoch: 890
# mse all (masked)patches: 0.09285622090101242
# all close: False
# Epoch: 891
# mse all (masked)patches: 0.09494578838348389
# all close: False
# Epoch: 892
# mse all (masked)patches: 0.09362786263227463
# all close: False
# Epoch: 893
# mse all (masked)patches: 0.09249386191368103
# all close: False
# Epoch: 894
# mse all (masked)patches: 0.09750834107398987
# all close: False
# Epoch: 895
# mse all (masked)patches: 0.09369806945323944
# all close: False
# Epoch: 896
# mse all (masked)patches: 0.09788879752159119
# all close: False
# Epoch: 897
# mse all (masked)patches: 0.09514486789703369
# all close: False
# Epoch: 898
# mse all (masked)patches: 0.09791480749845505
# all close: False
# Epoch: 899
# mse all (masked)patches: 0.09387695044279099
# all close: False
# Epoch: 900
# mse all (masked)patches: 0.0948096290230751
# all close: False
# Epoch: 901
# mse all (masked)patches: 0.0958024114370346
# all close: False
# Epoch: 902
# mse all (masked)patches: 0.09443160891532898
# all close: False
# Epoch: 903
# mse all (masked)patches: 0.09562230110168457
# all close: False
# Epoch: 904
# mse all (masked)patches: 0.09563787281513214
# all close: False
# Epoch: 905
# mse all (masked)patches: 0.09303497523069382
# all close: False
# Epoch: 906
# mse all (masked)patches: 0.09453827887773514
# all close: False
# Epoch: 907
# mse all (masked)patches: 0.09561777114868164
# all close: False
# Epoch: 908
# mse all (masked)patches: 0.09455171972513199
# all close: False
# Epoch: 909
# mse all (masked)patches: 0.09694818407297134
# all close: False
# Epoch: 910
# mse all (masked)patches: 0.09713298827409744
# all close: False
# Epoch: 911
# mse all (masked)patches: 0.09723382443189621
# all close: False
# Epoch: 912
# mse all (masked)patches: 0.09717274457216263
# all close: False
# Epoch: 913
# mse all (masked)patches: 0.09518064558506012
# all close: False
# Epoch: 914
# mse all (masked)patches: 0.09575144946575165
# all close: False
# Epoch: 915
# mse all (masked)patches: 0.09670798480510712
# all close: False
# Epoch: 916
# mse all (masked)patches: 0.09525343030691147
# all close: False
# Epoch: 917
# mse all (masked)patches: 0.09585599601268768
# all close: False
# Epoch: 918
# mse all (masked)patches: 0.09637647867202759
# all close: False
# Epoch: 919
# mse all (masked)patches: 0.0934678465127945
# all close: False
# Epoch: 920
# mse all (masked)patches: 0.09377682209014893
# all close: False
# Epoch: 921
# mse all (masked)patches: 0.09233825653791428
# all close: False
# Epoch: 922
# mse all (masked)patches: 0.09589643776416779
# all close: False
# Epoch: 923
# mse all (masked)patches: 0.09652549028396606
# all close: False
# Epoch: 924
# mse all (masked)patches: 0.09012114256620407
# all close: False
# Epoch: 925
# mse all (masked)patches: 0.09363330900669098
# all close: False
# Epoch: 926
# mse all (masked)patches: 0.09383684396743774
# all close: False
# Epoch: 927
# mse all (masked)patches: 0.09378132969141006
# all close: False
# Epoch: 928
# mse all (masked)patches: 0.09463471919298172
# all close: False
# Epoch: 929
# mse all (masked)patches: 0.09506525844335556
# all close: False
# Epoch: 930
# mse all (masked)patches: 0.09645497798919678
# all close: False
# Epoch: 931
# mse all (masked)patches: 0.09170262515544891
# all close: False
# Epoch: 932
# mse all (masked)patches: 0.09761334210634232
# all close: False
# Epoch: 933
# mse all (masked)patches: 0.09849527478218079
# all close: False
# Epoch: 934
# mse all (masked)patches: 0.09480041265487671
# all close: False
# Epoch: 935
# mse all (masked)patches: 0.09426068514585495
# all close: False
# Epoch: 936
# mse all (masked)patches: 0.09379865229129791
# all close: False
# Epoch: 937
# mse all (masked)patches: 0.0938999354839325
# all close: False
# Epoch: 938
# mse all (masked)patches: 0.09662433713674545
# all close: False
# Epoch: 939
# mse all (masked)patches: 0.095900759100914
# all close: False
# Epoch: 940
# mse all (masked)patches: 0.09698738157749176
# all close: False
# Epoch: 941
# mse all (masked)patches: 0.09321283549070358
# all close: False
# Epoch: 942
# mse all (masked)patches: 0.09450668096542358
# all close: False
# Epoch: 943
# mse all (masked)patches: 0.094060517847538
# all close: False
# Epoch: 944
# mse all (masked)patches: 0.0955059751868248
# all close: False
# Epoch: 945
# mse all (masked)patches: 0.09439146518707275
# all close: False
# Epoch: 946
# mse all (masked)patches: 0.09763700515031815
# all close: False
# Epoch: 947
# mse all (masked)patches: 0.09668084979057312
# all close: False
# Epoch: 948
# mse all (masked)patches: 0.09434664994478226
# all close: False
# Epoch: 949
# mse all (masked)patches: 0.09554171562194824
# all close: False
# Epoch: 950
# mse all (masked)patches: 0.09381704032421112
# all close: False
# Epoch: 951
# mse all (masked)patches: 0.09200722724199295
# all close: False
# Epoch: 952
# mse all (masked)patches: 0.09530128538608551
# all close: False
# Epoch: 953
# mse all (masked)patches: 0.09356793016195297
# all close: False
# Epoch: 954
# mse all (masked)patches: 0.09509509056806564
# all close: False
# Epoch: 955
# mse all (masked)patches: 0.09581015259027481
# all close: False
# Epoch: 956
# mse all (masked)patches: 0.0958411917090416
# all close: False
# Epoch: 957
# mse all (masked)patches: 0.09518695622682571
# all close: False
# Epoch: 958
# mse all (masked)patches: 0.09746260195970535
# all close: False
# Epoch: 959
# mse all (masked)patches: 0.09448167681694031
# all close: False
# Epoch: 960
# mse all (masked)patches: 0.09542274475097656
# all close: False
# Epoch: 961
# mse all (masked)patches: 0.09563227742910385
# all close: False
# Epoch: 962
# mse all (masked)patches: 0.09378333389759064
# all close: False
# Epoch: 963
# mse all (masked)patches: 0.09312561899423599
# all close: False
# Epoch: 964
# mse all (masked)patches: 0.09344135969877243
# all close: False
# Epoch: 965
# mse all (masked)patches: 0.09631715714931488
# all close: False
# Epoch: 966
# mse all (masked)patches: 0.09885092079639435
# all close: False
# Epoch: 967
# mse all (masked)patches: 0.10063052922487259
# all close: False
# Epoch: 968
# mse all (masked)patches: 0.09593400359153748
# all close: False
# Epoch: 969
# mse all (masked)patches: 0.09321855008602142
# all close: False
# Epoch: 970
# mse all (masked)patches: 0.09832177311182022
# all close: False
# Epoch: 971
# mse all (masked)patches: 0.09424596279859543
# all close: False
# Epoch: 972
# mse all (masked)patches: 0.09383273869752884
# all close: False
# Epoch: 973
# mse all (masked)patches: 0.09496928751468658
# all close: False
# Epoch: 974
# mse all (masked)patches: 0.09613549709320068
# all close: False
# Epoch: 975
# mse all (masked)patches: 0.09875994920730591
# all close: False
# Epoch: 976
# mse all (masked)patches: 0.09463000297546387
# all close: False
# Epoch: 977
# mse all (masked)patches: 0.09652470052242279
# all close: False
# Epoch: 978
# mse all (masked)patches: 0.0960085466504097
# all close: False
# Epoch: 979
# mse all (masked)patches: 0.09635419398546219
# all close: False
# Epoch: 980
# mse all (masked)patches: 0.09356957674026489
# all close: False
# Epoch: 981
# mse all (masked)patches: 0.09612584114074707
# all close: False
# Epoch: 982
# mse all (masked)patches: 0.09462849050760269
# all close: False
# Epoch: 983
# mse all (masked)patches: 0.09084930270910263
# all close: False
# Epoch: 984
# mse all (masked)patches: 0.0921381488442421
# all close: False
# Epoch: 985
# mse all (masked)patches: 0.09779561311006546
# all close: False
# Epoch: 986
# mse all (masked)patches: 0.09413997828960419
# all close: False
# Epoch: 987
# mse all (masked)patches: 0.09532200545072556
# all close: False
# Epoch: 988
# mse all (masked)patches: 0.09282392263412476
# all close: False
# Epoch: 989
# mse all (masked)patches: 0.09269218891859055
# all close: False
# Epoch: 990
# mse all (masked)patches: 0.09311262518167496
# all close: False
# Epoch: 991
# mse all (masked)patches: 0.0936117097735405
# all close: False
# Epoch: 992
# mse all (masked)patches: 0.09649363160133362
# all close: False
# Epoch: 993
# mse all (masked)patches: 0.0938173457980156
# all close: False
# Epoch: 994
# mse all (masked)patches: 0.0921391025185585
# all close: False
# Epoch: 995
# mse all (masked)patches: 0.09324530512094498
# all close: False
# Epoch: 996
# mse all (masked)patches: 0.09508305042982101
# all close: False
# Epoch: 997
# mse all (masked)patches: 0.09136485308408737
# all close: False
# Epoch: 998
# mse all (masked)patches: 0.09325723350048065
# all close: False
# Epoch: 999
# mse all (masked)patches: 0.09677261114120483
# all close: False
# Epoch: 1000
# mse all (masked)patches: 0.09493381530046463
# all close: False

# %%
# 推理
# 模型重建的效果图，mask 效果图
recons_img_ts, masked_img_ts = mae.predict(img_ts)
recons_img_ts, masked_img_ts = recons_img_ts.cpu().squeeze(0), masked_img_ts.cpu().squeeze(0)

# 将结果保存下来以便和原图比较
recons_img = ToPILImage()(recons_img_ts)
recons_img.save(os.path.join(BASE_DIR, 'recons_photo.jpg'))

masked_img = ToPILImage()(masked_img_ts)
masked_img.save(os.path.join(BASE_DIR, 'masked_photo.jpg'))

# 画图
img = Image.open(os.path.join(BASE_DIR, 'photo.jpg'))
plt.figure("original photo")  # 图像窗口名称
plt.imshow(img)
plt.axis('off')  # 关掉坐标轴为 off
plt.title('original photo')  # 图像题目
plt.show()

img = Image.open(os.path.join(BASE_DIR, 'masked_photo.jpg'))
plt.figure("masked photo")  # 图像窗口名称
plt.imshow(img)
plt.axis('off')  # 关掉坐标轴为 off
plt.title('masked photo')  # 图像题目
plt.show()

img = Image.open(os.path.join(BASE_DIR, 'recons_photo.jpg'))
plt.figure("reconstructed photo")  # 图像窗口名称
plt.imshow(img)
plt.axis('off')  # 关掉坐标轴为 off
plt.title('reconstructed photo')  # 图像题目
plt.show()
# Out:
# mse per (masked)patch: tensor([[0.1299, 0.0321, 0.0783, 0.2180, 0.1312, 0.0802, 0.1562, 0.0800, 0.0876,
#          0.1425, 0.0380, 0.0813, 0.0786, 0.1710, 0.0866, 0.1254, 0.1642, 0.0266,
#          0.1014, 0.1074, 0.0532, 0.0323, 0.1165, 0.1435, 0.1048, 0.0954, 0.0441,
#          0.1398, 0.0759, 0.1277, 0.1184, 0.0465, 0.1268, 0.1692, 0.0805, 0.0801,
#          0.0615, 0.1143, 0.1363, 0.0737, 0.0963, 0.0805, 0.1187, 0.1506, 0.0985,
#          0.0936, 0.1362, 0.0253, 0.1061, 0.1410, 0.0793, 0.1610, 0.0939, 0.1753,
#          0.0303, 0.1295, 0.0454, 0.0700, 0.0435, 0.0920, 0.0361, 0.1130, 0.1794,
#          0.0492, 0.0776, 0.1087, 0.0930, 0.0226, 0.0227, 0.1179, 0.1398, 0.0889,
#          0.1239, 0.0232, 0.1373, 0.0332, 0.1269, 0.0219, 0.1280, 0.0822, 0.0741,
#          0.0284, 0.0755, 0.0894, 0.1242, 0.1333, 0.1426, 0.0920, 0.1097, 0.1493,
#          0.1249, 0.1605, 0.1836, 0.0836, 0.0837, 0.1316, 0.0678, 0.0281, 0.0868,
#          0.0201, 0.0568, 0.0191, 0.1465, 0.0840, 0.1344, 0.0725, 0.0648, 0.0936,
#          0.1108, 0.1485, 0.0739, 0.0930, 0.0524, 0.2150, 0.1158, 0.0925, 0.0372,
#          0.0913, 0.0316, 0.1559, 0.1547, 0.0600, 0.0832, 0.1187, 0.1782, 0.2049,
#          0.1086, 0.1358, 0.1404, 0.2410, 0.0138, 0.0746, 0.0492, 0.0849, 0.0832,
#          0.0964, 0.0644, 0.1360, 0.0728, 0.0286, 0.0426, 0.0700, 0.0947, 0.0962,
#          0.1918, 0.0853, 0.1062]], device='cuda:0', grad_fn=<MeanBackward1>) mse all (masked)patches: 0.09826221317052841 total 147 masked patches
# all close: False

# %%
# %reload_ext tensorboard
# %tensorboard --logdir '/home/Insight/runs'
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %% [markdown]
# # 完成任务之后，把输出的材料保存到google drive
# * 因为虚拟机上的东西生命周期到了就消失了

# %%
# 复制tensorboard记录
# !/bin/cp -rf /home/Insight/runs/*  /content/drive/MyDrive/Insight/runs
print('runs copy completed!')
# 复制saved models模型参数
# !/bin/cp -rf /home/Insight/saved_models/* /content/drive/MyDrive/Insight/saved_models
print('models copy completed!')
# Out:
# runs copy completed!
# models copy completed!

# %% [markdown]
# ## 显示时间

# %%
# 如果一段时间不需要用显卡的话，可以整个僵尸参数占用点显存，避免出现警告
# import torch
# a = torch.Tensor([1000, 1000, 1000]).cuda()  # 大约占用 1.1G 显存
# !date --date='+8 hour'  # 查看系统时间，转换为北京时间
# Out:
# Sun Apr 17 15:48:27 UTC 2022
